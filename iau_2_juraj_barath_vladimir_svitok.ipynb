# %% [markdown]
# # Intellligent Data Analysis
#
# - **Data Set:** #31
# - **Author 1:** Vladimír Svitok
# - **Author 2:** Juraj Baráth

# %% [markdown]
# ## Prieskumná analýza (max. 12b)
# Prieskumná analýza je kľúčovou časťou analýzy dát. Bez nej nie sme schopní dáta spracúvať, pretože nevieme, čo sa v nich nachádza. Využíva sa  pritom predovšetkým deskriptívna štatistika a rôzne podporné vizualizácie.
#
# V tejto fáze sa od vás očakáva:
#
# - **Základný opis dát spolu s ich charakteristikami (3b).** Pre dosiahnutie plného počtu bodov uveďte počet záznamov, počet atribútov, ich typy a pre zvolené významné atribúty ich distribúcie, základné deskriptívne štatistiky a pod.
# - **Párová analýza dát (4b).** Preskúmajte vzťahy medzi zvolenými dvojicami atribútov. Zamerajte sa pritom na identifikáciu závislostí medzi dvojicami atribútov (napr. korelácie) a na závislosti medzi predikovanou premennou a ostatnými premennými (potenciálnymi prediktormi).
# - **Formulácia a štatistické overenie hypotéz o dátach (2b).** Mali by ste sformulovať aspoň dve hypotézy o dátach, ktoré budú relevantné v kontexte zadanej predikčnej úlohy. Príkladom hypotézy (v závislosti od pridelenej dátovej sady) môže byť, že *pacienti s chorobou štítnej žľazy majú v priemere inú (vyššiu/nižšiu) hodnotu nejakej látky alebo hormónu ako pacienti bez danej choroby*. Vami sformulované hypotézy overte vhodne zvoleným štatistickým testom.
# - **Identifikácia problémov v dátach spolu s predpokladaným scenárom riešenia v ďalšej fáze (3b).** Mali by ste identifikovať, čo budete musieť v rámci predspracovania vyriešiť (aj s naznačením možností, ako tieto problémy plánujete v ďalšej fáze riešiť). Medzi problémy, na ktoré môžete v rámci analýzy naraziť, patria napr.:
#    - nevhodná štruktúra dát (dáta nie sú v tabuľkovej podobe alebo jedna entita je opísaná viacerými riadkami tabuľky)
#    - duplicitné záznamy, resp. nejednoznačné mapovanie medzi záznamami
#    - nejednotné formáty dát
#    - chýbajúce hodnoty
#    - vychýlené (odľahlé) hodnoty
#    - a ďalšie, t. j. v dátach sa môžu nachádzať aj iné, tu nevymenované problémy, ktoré tiež treba identifikovať a vo vašej analýze adresovať.
#
# V odovzdanej správe (`Jupyter Notebooku`) by ste tak mali vedieť zodpovedať na otázky:
# - Majú dáta vhodný formát pre ďalšie spracovanie? Ak nie, aké problémy sa v nich vyskytujú?
# - Sú niektoré atribúty medzi sebou závislé? Od ktorých (jednotlivých) atribútov závisí predikovaná premenná?
# - Sú v dátach chýbajúce hodnoty? Ako sú reprezentované? Ako plánujete riešiť problém chýbajúcich hodnôt pre jednotlivé atribúty, resp. pozorovania? (Pre rôzne atribúty môže byť vhodné použiť rôzne stratégie.)
# - Nadobúdajú niektoré atribúty nezmyselné (nekonzistentné) či inak výrazne odchýlené hodnoty? Ktoré?
# - Ako plánujete v ďalšej fáze tieto identifikované problémy adresovať / riešiť?
#
# Správa sa odovzdáva v 6. týždni semestra na cvičení (dvojica svojmu cvičiacemu odprezentuje vykonanú prieskumnú analýzu v `Jupyter Notebooku`). Následne správu elektronicky odovzdá jeden člen z  dvojice do systému AIS do **nedele 3.11.2019 do 23:59**.
#
#
#
# ## Dataset: personal_train
#
# - **Počet záznamov:** 3933
# - **Počet atribútov:** 6
#
# ### Zoznam atribútov, problémi a riešenia
#
#
# | Atribút           | Typ             | Popis                    | Problémi a ich riešenia        |
# |:------------------|:----------------|:-------------------------|:-------------------------------|
# | **Unnamed: 0**    | int             | Identifikačné číslo pacienta | Stĺpec nemá správny názov, máme to premenovať na **id** |
# | **name**          | string          | Meno pacienta            | Žiadne |
# | **address**       | multi-line string | Domovská adresa pacienta | Žiadne                         | Netreba nič riešiť
# | **age**           | int             | Vek pacienta             | Niektoré záznamy neobsahujú vek pacienta. |
# |                   |                 | | Namiesto veku sa v záznamoch nachádzajú "?" alebo "NaN"   |
# |                   |                 | | Tieto chýbajúce hodnoty budeme počítať z dátumu narodania |
# | **sex**           | enum            | Pohlavie pacienta | Hodnoty začínajú zbytočným medzerom, ktoré musíme odstrániť, môže mať hodnoty "Male" a "Female"  |
# | **date_of_birth** | date            | Dátum narodenia | Obsahuje rôzne formáty. Zjednotíme do tvaru: yyyy-mm-dd   |
#
#
#
#
# ## Dataset: other_train
#
# - **Počet záznamov:** 3983
# - **Počet atribútov:** 23
#
# |  Attribút            | Typ    |  Popis  | Problémi a ich riešenia, použitie údajov
# |:---------------------|:--------|:-----|:----|
# | **Unnamed: 0**       | int  | Identifikačné číslo pacienta | Stĺpec nemá správny názov, máme to premenovať na **id** |
# | **name**             | string  | Meno pacienta |Podľa mena budeme spájať tabuľky **presonal_train** a **other_train** pretože atribúť **age** považujeme relevantný k výsledkom, ktoré sa snažíme zistiť |
# | **address**          | multi-line string | Domovská adresa pacienta | Budeme používať v prípade duplicitných mien, Pokiaľ budú adresy rovnaké vieme, že sa jedná o toho istého pacienta, pokiaľ rozdielne tak sú to záznamy rôznych pacientov|
# | **race**             | enum  | Pôvodnosť pacienta  | Môže byť užitočné, ako kritéria na vygenerovanie štatistík údajov, má zbytočné medzeri
# | **marital-status**   | enum  | Rodinný stav pacienta | Predpokladáme že nie je významný pre našu predikovanú premennú|
# | **occupation**       | enum  | Povolenie pacienta | Predpokladáme že nie je významný pre našu predikovanú premennú|
# | **pregnant**         | bool  | Tehotnosť pacienta | Obsahuje rôzne formáty dát. Pretypujeme na bool hodnotu|
# | **education-num**    | int   | Stupeň štúdia (číselne vyjadrené) | Predpokladáme že nie je významný pre našu predikovanú premennú |
# | **relationship**     | enum  | Ľudské vzťahy pacienta | Predpokladáme že nie je významný pre našu predikovanú premennú |
# | **skewness_glucose** | float | Šikmosť glukóza | Z grafu vidíme, že hodnoty sú v priemere výrazne vyššie u ľudí, ktorým bola diagnostikovaná choroba |
# |**mean_glucose**     | float | Stredná glukóza | Z grafu vidíme, že hodnoty sú v priemere nižšie u ľudí, ktorým bola diagnostikovaná choroba|
# |**capital-gain**     | float | Kapitáloví zisk | Predpokladáme že nie je významný pre našu predikovanú premennú|
# |**kurtosis_glucose** | float | Kurtózia glukóza | Z grafu vidíme, že hodnoty sú v priemere výrazne vyššie u ľudí, ktorým bola diagnostikovaná choroba|
# |**education**        | string | Stupeň štúdia (slovne opísané) | Predpokladáme že nie je významný pre našu predikovanú premennú |
# |**fnlwgt**           | float | Nevieme presne čo to znamená | Predpokladáme že nie je významný pre našu predikovanú premennú |
# |**class**            | bool | Klasifikácia pacienta, či má cukrovku, alebo nemá | Nemá žiadne problémi, je to kritický údaj pri analýzi ostatných údajov, používame to ako hlavný filter pri vygenerovaní grafov |
# |**std_glucose**      | float | Štandard glukóza | V tomto stĺpci sa nachádzajú odchýlené hodnoty, ktoré vidno v tabuľke o dátach aj v grafoch. Minimálna hodnota okolo -6000 a maximálna okolo 7500 značí že bude treba tieto údaje prehodnotiť a vypočítať nové, ktoré budú presné.|
# |**income**           | float    | Príjem | Predpokladáme že nie je významný pre našu predikovanú premennú|
# |**medical_info**     | 4 floats | Hodnoty meraní kyslíka | Hodnoty meraní kyslíka sú zapísané vo formáte JSON. Ten spracujeme a rozdelíme do 4 rôznych stĺpcov: mean_oxygen, std_oxygen, kurtosis_oxygen, skewness_oxygen |
# |**mean_oxygen**      | float | Stredný kyslík | Z grafu vidíme, že pacienti s chorobou majú priemerne trochu vyššie hodnoty ako zdravý pacienti, no nedá sa priamo určiť stav pacienta|
# |**std_oxygen**       | float | Štandard kyslíka | Z grafu vidíme, že pacienti s chorobou majú priemerne vyššie hodnoty ako zdravý pacienti, no nedá sa priamo určiť stav pacienta|
# |**kurtosis_oxygen**  | float | Kurtózia kyslíka | Z grafu vidíme, že pacienti s chorobou majú priemerne nižšie hodnoty ako zdravý pacienti no nedá sa priamo určiť stav pacienta|
# |**skewness_oxygen**  | float | Šikmosť kyslíka | Z grafu vidíme, že pacienti s chorobou majú priemerne nižšie hodnoty ako zdravý pacienti, no nedá sa priamo určiť stav pacienta|
# |**native-country**   | string | Rodná krajina | Predpokladáme že nie je významný pre našu predikovanú premennú |
# |**hours-per-week**   | float  | Týždenne zapracované hodiny | Predpokladáme že nie je významný pre našu predikovanú premennú|
# |**capital-loss**     | float  | Kapitálová strata | Predpokladáme že nie je významný pre našu predikovanú premennú|
#
# ### Medzi významné atribúty sme zaradili
# - age
# - class
# - kurtosis_glucose
# - mean_glucose
# - medical_info
# - name
# - pregnant
# - race
# - sex
# - skewness_glucose
# - std_glucose
#
# Predpokladáme že tieto atribúty môžu mať vplyv na našu predikovanú premennú
#
# Vidíme že:  **skewness_oxygen** a **skewness_glucose** spolu nepriamo súvisia,
#             **mean_glucose** a **mean_oxygen** spolu nepriamo súvisia,
#             **kurtosis_glucose** a **kurtosis_oxygen** spolu nepriamo súvisia,
# Na základe týchto zistení by sme mali byť schopný určiť stav pacienta.
#
# V štatistickej tabuľke vidno že merania hodnôt cukru spolu priamo úmerne súvisia.
#
# ## Korelácie
#
# ### Pozitívne (>0.5)
#
# - **skewness_glucose:** kurtosis_glucose (0.962056), class (0.680059), mean_oxygen (0.550525), std_oxygen (0.55682)
# - **kurtosis_glucose:** class (0.787698), mean_oxygen (0.594049), std_oxygen (0.61698)
# - **class:** mean_oxygen (0.514376), std_oxygen (0.641619)
# - **mean_oxygen:** std_oxygen (0.801483)
# - **kurtosis_oxygen:** skewness_oxygen (0.916746)
#
# ### Negatívne (<-0.5)
#
# - **skewness_glucose:** mean_glucose (-0.826373)
# - **mean_glucose:** kurtosis_glucose (-0.925739), class (-0.77454), mean_oxygen (-0.54111), std_oxygen (-0.556414)
# - **kurtosis_glucose:** kurtosis_oxygen (-0.525496)
# - **class:** kurtosis_oxygen (-0.556507)
# - **mean_oxygen:** kurtosis_oxygen (-0.653326)
# - **std_oxygen:** kurtosis_oxygen (-0.825101), skewness_oxygen (-0.596467)
#
#
# ## Hypotézy
#
# - **1.** Ľudia s vyššími hodnotami výsledkov merania cukru sú nachylnejší na pozitívnemu výsledky na chorobu
# - **2.** Ľudia s nižšími hodnotami výsledkov merania kyslíka sú náchylnejší k pozitívnemu výsledku na chorobu

# %%
# Automatically reformat python code
# Check https://medium.com/openplanetary/code-formatting-in-jupyter-cells-8fee4eda072f for more info
# %load_ext lab_black

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
import json
import seaborn as sea
import math

# %%
data = pd.read_csv("personal_train.csv")

# %%
data2 = pd.read_csv("other_train.csv")

# %%
# Check how does the personal train data (data) look like
data.head(30)
# Out:
#     Unnamed: 0                  name  \
# 0            0       Roscoe Bohannon
# 1            1          Ernest Kline
# 2            2       Harold Hendriks
# 3            3        Randy Baptiste
# 4            4       Anthony Colucci
# 5            5          Ronald Lange
# 6            6         Boyd Eiselein
# 7            7         Raymond Smith
# 8            8         Harold Miller
# 9            9  Charles Czachorowski
# 10          10       Robert Grantham
# 11          11              Joel Lam
# 12          12            Irving Gil
# 13          13        Terry Reynolds
# 14          14      Kurt Littlefield
# 15          15          Andy Grayson
# 16          16       Chauncey Suarez
# 17          17        Wallace Street
# 18          18       Daniel Crossman
# 19          19            Steve Ripp
# 20          20       George Hairston
# 21          21        Jeffrey Taylor
# 22          22           David Mealy
# 23          23        Garfield Bowen
# 24          24      Thaddeus Mackerl
# 25          25           Gerald Pack
# 26          26       Jonathon Nemith
# 27          27           Roger Groce
# 28          28          Harold Odowd
# 29          29       Stanley Forrest
#
#                                               address  age      sex  \
# 0   7183 Osborne Ways Apt. 651\r\nEast Andrew, OH ...   60     Male
# 1   391 Ball Road Suite 961\r\nFlowersborough, IN ...   52     Male
# 2      8702 Vincent Square\r\nNew Jerryfurt, CO 30614   60     Male
# 3      2751 Harris Crossroad\r\nWest Ashley, CA 30311   39     Male
# 4   904 Robert Cliffs Suite 186\r\nWest Kyle, CO 7...   49     Male
# 5         30973 Martinez Shores\r\nJameston, CA 70245   46     Male
# 6   29941 Christopher Curve Apt. 682\r\nRaychester...   54   Female
# 7   53487 Scott Extensions Apt. 824\r\nMccartytown...   67     Male
# 8   8514 Elizabeth Crescent\r\nWest Joseland, GA 4...   52     Male
# 9   6798 Wagner Locks Suite 377\r\nLake Brenda, DC...   30     Male
# 10            822 Adams Plains\r\nNew Karen, AK 92114   38     Male
# 11  61296 Reginald Rapids Suite 783\r\nWest Timoth...   62     Male
# 12  90757 Amanda Views Suite 604\r\nPort Paul, TX ...   56     Male
# 13  0019 Jensen Land Apt. 513\r\nPort Timothyville...   76     Male
# 14       822 Wilson Meadow\r\nMitchellmouth, RI 05935  NaN     Male
# 15            2573 Ryan Mission\r\nShortton, DC 01129   67     Male
# 16      481 Wilson Prairie\r\nKimberlymouth, LA 20064   46   Female
# 17          9909 John Creek\r\nEast Heather, NY 31266   44     Male
# 18   74669 Robles Drive\r\nPort Madisonbury, LA 63565   45     Male
# 19           7629 Ramos Knoll\r\nOwensmouth, NC 34420   54   Female
# 20      18356 Benjamin Roads\r\nSouth Nancy, NJ 58120   51     Male
# 21                           USNV Kim\r\nFPO AA 96043   39   Female
# 22          0873 Diaz Village\r\nSandrastad, DE 05796   53     Male
# 23   3678 Gloria Pine Apt. 652\r\nKevinfort, LA 80839   54     Male
# 24  8122 Jessica Knolls Apt. 880\r\nDakotafurt, WV...   47     Male
# 25       6146 Roman Shores\r\nNew Christine, OR 28920   55     Male
# 26            875 David Road\r\nPhillipfort, NC 26174   51     Male
# 27          781 Berry Spring\r\nTravismouth, NJ 11603   46   Female
# 28  7842 Curtis Vista Apt. 188\r\nLake Samuelburgh...   55     Male
# 29  9532 Jesse Roads Suite 253\r\nNorth Toni, NC 7...   52     Male
#
#           date_of_birth
# 0            1959-09-26
# 1            1966-10-28
# 2            1959-06-16
# 3            1980-09-09
# 4            1970-02-22
# 5            1973-09-25
# 6            1964-10-31
# 7            1952-07-23
# 8            1967-06-28
# 9            1988-11-07
# 10           1981-05-01
# 11           1957-08-10
# 12           16/11/1962
# 13           21/04/1943
# 14           1985-11-03
# 15           1952-08-06
# 16           1973-06-27
# 17           1975-01-10
# 18           1973-12-24
# 19           1965-05-06
# 20           1968-09-07
# 21  1980-06-11 00 00 00
# 22           1966-10-21
# 23           1965/04/25
# 24           1972-07-10
# 25           1963-12-19
# 26           1968-03-02
# 27           1972-12-11
# 28           1963-12-06
# 29  1967-09-04 00:00:00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933 entries, 0 to 3932
# Data columns (total 6 columns):
# Unnamed: 0       3933 non-null int64
# name             3933 non-null object
# address          3933 non-null object
# age              3658 non-null object
# sex              3933 non-null object
# date_of_birth    3933 non-null object
# dtypes: int64(1), object(5)
# memory usage: 184.4+ KB

# %%
# Rename the 'Unnamed: 0' column to 'id'
data.rename(columns={data.columns[0]: "id"}, inplace=True)
data2.rename(columns={data2.columns[0]: "id"}, inplace=True)

# %%
# Plot the age column
data["age"] = pd.to_numeric(data["age"], errors="coerce")
data["age"].plot.kde()

# %%
data.describe()
# Out:
#                 id          age
# count  3933.000000  3540.000000
# mean   1966.000000    51.848870
# std    1135.503633    11.787179
# min       0.000000    -1.000000
# 25%     983.000000    45.000000
# 50%    1966.000000    52.000000
# 75%    2949.000000    60.000000
# max    3932.000000    99.000000

# %%
data.corr()
# Out:
#            id       age
# id   1.000000  0.008267
# age  0.008267  1.000000

# %%
# Check how does the other train data (data2) look like
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3983 entries, 0 to 3982
# Data columns (total 23 columns):
# id                  3983 non-null int64
# name                3983 non-null object
# address             3983 non-null object
# race                3963 non-null object
# marital-status      3972 non-null object
# occupation          3973 non-null object
# pregnant            3969 non-null object
# education-num       3969 non-null float64
# relationship        3969 non-null object
# skewness_glucose    3970 non-null float64
# mean_glucose        3970 non-null float64
# capital-gain        3974 non-null float64
# kurtosis_glucose    3972 non-null float64
# education           3963 non-null object
# fnlwgt              3975 non-null float64
# class               3970 non-null float64
# std_glucose         3576 non-null float64
# income              3968 non-null object
# medical_info        3965 non-null object
# native-country      3969 non-null object
# hours-per-week      3968 non-null float64
# capital-loss        3972 non-null float64
# workclass           3968 non-null object
# dtypes: float64(10), int64(1), object(12)
# memory usage: 715.8+ KB

# %%
# Check how does the other train data (data2) look like
data2.head(30)
# Out:
#     id              name                                            address  \
# 0    0        Mike Riley  023 Joseph Estate Suite 799\r\nLake Andrewvill...
# 1    1     Earl Hoffmann            700 Darlene Mill\r\nJackburgh, GA 99369
# 2    2      Lorenzo Mann   56863 Stephen Island\r\nSouth Danielle, NV 40760
# 3    3    Justin Trevino   18446 Pace Junction\r\nNew Christyfurt, SD 32280
# 4    4      Thomas Davis      67753 Wilson Ford\r\nNew Rachelport, NV 50148
# 5    5        Lynn Quist         2232 Flores Ridge\r\nSanchezstad, IL 31455
# 6    6    Roscoe Shelton  6954 Carrillo Shoals Apt. 139\r\nSandersview, ...
# 7    7       Jose Aigner       76756 Ashley Mount\r\nGomezchester, NV 49283
# 8    8      Robert Gerke        820 Mark Drives\r\nMichaelchester, OH 64396
# 9    9     Andre Bennett         25878 Hector Canyon\r\nJerryfurt, AZ 38098
# 10  10       Carson Judy      9121 Steven Lake\r\nNew Christopher, NC 18321
# 11  11       John Reeves           1111 Lisa Roads\r\nMatthewfurt, MN 95571
# 12  12  Kevin Richardson  2847 Tracy Mission Suite 159\r\nLyonschester, ...
# 13  13       William Rao  27786 Perez Mall Suite 843\r\nLake Parkerton, ...
# 14  14      John Whisler  50702 Wu Springs Suite 692\r\nNew Curtis, NE 7...
# 15  15    Andre Mcdonald          448 Miller Ports\r\nLake Samuel, FL 25888
# 16  16   Cedric Matthews         2010 Ross Place\r\nRodriguezport, NH 07286
# 17  17       Roy Colella          7226 Green Tunnel\r\nNorth Lisa, NC 23945
# 18  18        James Chau         21561 Mary Spring\r\nJosephhaven, SD 61945
# 19  19       Jose Fraser       521 Gallegos Islands\r\nWest Brian, KS 37357
# 20  20       Byron Saari      520 Amanda Path\r\nPort Loriborough, AR 42069
# 21  21   Manuel Trombley  1525 Henry Station Suite 174\r\nEast Marcshire...
# 22  22         John Hart                 Unit 0995 Box 2264\r\nDPO AE 51337
# 23  23       Joseph Conn                 PSC 8070, Box 8717\r\nAPO AE 45843
# 24  24  Claude Rodriguez    31740 Jeffrey Falls\r\nPort Faithstad, IA 94696
# 25  25        Jody Nalls  69736 John Shoal Apt. 744\r\nJenkinstown, TN 6...
# 26  26      Edwin Laster  392 Jones Place Suite 295\r\nNorth Jared, IN 0...
# 27  27    Bryon Gallegos         7923 Perez Route\r\nLake Vincent, MO 14843
# 28  28       Raul Sutton  7326 Rodriguez Mountains Apt. 840\r\nAshleyton...
# 29  29      Jesse Seaton                        USS Sanchez\r\nFPO AA 92212
#
#                    race       marital-status          occupation pregnant  \
# 0                 White   Married-civ-spouse      Prof-specialty        f
# 1                 White             Divorced        Craft-repair        f
# 2                 White             Divorced        Craft-repair        t
# 3                 White        Never-married        Tech-support        f
# 4                 White   Married-civ-spouse    Transport-moving        f
# 5                 White             Divorced    Transport-moving        f
# 6                 White   Married-civ-spouse        Adm-clerical        f
# 7                 White             Divorced               Sales        f
# 8                 White   Married-civ-spouse               Sales        F
# 9                 White        Never-married      Prof-specialty        f
# 10                White        Never-married       Other-service        f
# 11                White        Never-married     Exec-managerial        f
# 12                White   Married-civ-spouse   Machine-op-inspct        f
# 13                White   Married-civ-spouse     Protective-serv        f
# 14                White   Married-civ-spouse     Farming-fishing        f
# 15                White             Divorced        Tech-support        f
# 16                White              Widowed     Exec-managerial        f
# 17   Amer-Indian-Eskimo   Married-civ-spouse        Adm-clerical        t
# 18                White        Never-married     Exec-managerial        f
# 19                White   Married-civ-spouse     Exec-managerial        f
# 20                White             Divorced        Adm-clerical        f
# 21                White   Married-civ-spouse       Other-service        f
# 22                White   Married-civ-spouse        Tech-support        f
# 23                White   Married-civ-spouse   Handlers-cleaners        f
# 24                Black             Divorced   Machine-op-inspct        f
# 25                White   Married-civ-spouse               Sales        f
# 26                White        Never-married        Adm-clerical        f
# 27                White   Married-civ-spouse   Handlers-cleaners        f
# 28                White             Divorced        Tech-support        f
# 29                White   Married-civ-spouse   Handlers-cleaners        f
#
#     education-num    relationship  skewness_glucose  ...      education  \
# 0            12.0         Husband          1.605420  ...     Assoc-acdm
# 1             9.0       Unmarried         10.994893  ...        HS-grad
# 2            10.0   Not-in-family         -0.290893  ...   Some-college
# 3            13.0   Not-in-family         13.476089  ...      Bachelors
# 4             9.0         Husband          0.680234  ...        HS-grad
# 5             9.0   Not-in-family          1.315007  ...        HS-grad
# 6            13.0         Husband          2.731511  ...      Bachelors
# 7            13.0   Not-in-family          2.022478  ...      Bachelors
# 8            10.0         Husband          0.169639  ...   Some-college
# 9            11.0   Not-in-family          0.743007  ...      Assoc-voc
# 10            9.0       Unmarried          6.810020  ...        HS-grad
# 11           10.0       Own-child          0.732969  ...   Some-college
# 12            9.0         Husband         -0.244356  ...        HS-grad
# 13           11.0         Husband         -0.317422  ...      Assoc-voc
# 14           13.0         Husband         -0.252281  ...      Bachelors
# 15           10.0   Not-in-family         -0.034468  ...   Some-college
# 16            9.0   Not-in-family          6.426509  ...        HS-grad
# 17           13.0       Own-child         27.688922  ...      Bachelors
# 18           13.0   Not-in-family          0.348163  ...      Bachelors
# 19            9.0         Husband         -0.169973  ...        HS-grad
# 20            9.0   Not-in-family          4.229062  ...        HS-grad
# 21            6.0         Husband          0.275385  ...           10th
# 22            9.0         Husband          0.409075  ...        HS-grad
# 23            9.0         Husband         -0.403627  ...        HS-grad
# 24            9.0       Own-child         -0.275503  ...        HS-grad
# 25           13.0         Husband         35.520105  ...      Bachelors
# 26           10.0       Own-child          0.574901  ...   Some-college
# 27            9.0         Husband         -0.210235  ...        HS-grad
# 28           10.0   Not-in-family          0.121619  ...   Some-college
# 29           10.0         Husband          1.441155  ...   Some-college
#
#       fnlwgt  class std_glucose  income  \
# 0   251396.0    0.0   37.450318    >50K
# 1   157446.0    1.0   33.842927   <=50K
# 2   106014.0    0.0   51.123164   <=50K
# 3   189590.0    1.0   45.923142   <=50K
# 4   134768.0    0.0   46.867134    >50K
# 5   143542.0    0.0   40.466252   <=50K
# 6   259840.0    0.0   35.750382   <=50K
# 7   364548.0    0.0   39.279398    >50K
# 8   114520.0    0.0   49.502052   <=50K
# 9   436770.0    0.0   40.479149   <=50K
# 10  217030.0    1.0   34.902038   <=50K
# 11   86860.0    0.0   42.969091   <=50K
# 12  296317.0    0.0         NaN   <=50K
# 13  392668.0    0.0         NaN    >50K
# 14  271753.0    0.0   53.694409   <=50K
# 15  237833.0    0.0         NaN   <=50K
# 16  113324.0    1.0         NaN   <=50K
# 17   31387.0    1.0         NaN   <=50K
# 18  135296.0    0.0   50.163444    >50K
# 19  368797.0    0.0   48.177750   <=50K
# 20  113176.0    1.0   40.519002   <=50K
# 21  163870.0    0.0   45.160953   <=50K
# 22  177647.0    0.0   44.350158    >50K
# 23  250791.0    0.0   52.601631   <=50K
# 24  508891.0    0.0   52.411959   <=50K
# 25  121124.0    1.0   31.063859    >50K
# 26  186014.0    0.0         NaN   <=50K
# 27  112077.0    0.0   56.990465   <=50K
# 28  168625.0    0.0   42.953600    >50K
# 29  173851.0    0.0   42.494841   <=50K
#
#                                          medical_info  native-country  \
# 0   {'mean_oxygen':'10.03511706','std_oxygen':'35....          Canada
# 1   {'mean_oxygen':'7.834448161','std_oxygen':'33....   United-States
# 2   {'mean_oxygen':'3.505852843','std_oxygen':'19....   United-States
# 3   {'mean_oxygen':'83.55351171','std_oxygen':'66....   United-States
# 4   {'mean_oxygen':'2.602842809','std_oxygen':'18....   United-States
# 5   {'mean_oxygen':'4.886287625','std_oxygen':'24....   United-States
# 6   {'mean_oxygen':'1.705685619','std_oxygen':'17....   United-States
# 7   {'mean_oxygen':'2.117056856','std_oxygen':'15....   United-States
# 8   {'mean_oxygen':'5.197324415','std_oxygen':'26....   United-States
# 9   {'mean_oxygen':'0.766722408','std_oxygen':'9.5...   United-States
# 10  {'mean_oxygen':'15.68394649','std_oxygen':'49....   United-States
# 11  {'mean_oxygen':'0.984113712','std_oxygen':'10....   United-States
# 12  {'mean_oxygen':'2.195652174','std_oxygen':'16....          Mexico
# 13  {'mean_oxygen':'2.384615385','std_oxygen':'15....   United-States
# 14  {'mean_oxygen':'3.151337793','std_oxygen':'21....   United-States
# 15  {'mean_oxygen':'5.050167224','std_oxygen':'27....   United-States
# 16  {'mean_oxygen':'20.9632107','std_oxygen':'53.4...   United-States
# 17  {'mean_oxygen':'14.42725753','std_oxygen':'44....   United-States
# 18  {'mean_oxygen':'10.090301','std_oxygen':'38.94...   United-States
# 19  {'mean_oxygen':'1.272575251','std_oxygen':'15....   United-States
# 20  {'mean_oxygen':'8.204849498','std_oxygen':'39....   United-States
# 21  {'mean_oxygen':'1.08361204','std_oxygen':'11.4...   United-States
# 22  {'mean_oxygen':'7.419732441','std_oxygen':'30....          France
# 23  {'mean_oxygen':'1.048494983','std_oxygen':'10....   United-States
# 24  {'mean_oxygen':'2.43645485','std_oxygen':'19.5...   United-States
# 25  {'mean_oxygen':'58.11371237','std_oxygen':'66....   United-States
# 26  {'mean_oxygen':'4.62541806','std_oxygen':'28.2...   United-States
# 27  {'mean_oxygen':'4.431438127','std_oxygen':'23....   United-States
# 28  {'mean_oxygen':'1.739966555','std_oxygen':'12....   United-States
# 29  {'mean_oxygen':'1.276755853','std_oxygen':'16....   United-States
#
#    hours-per-week capital-loss          workclass
# 0            45.0          0.0          Local-gov
# 1            45.0          0.0            Private
# 2            60.0          0.0            Private
# 3            40.0          0.0            Private
# 4            40.0          0.0            Private
# 5            40.0          0.0            Private
# 6            45.0          0.0            Private
# 7            40.0          0.0            Private
# 8            40.0          0.0   Self-emp-not-inc
# 9            40.0          0.0            Private
# 10           30.0          0.0   Self-emp-not-inc
# 11           15.0          0.0            Private
# 12           40.0          0.0            Private
# 13           40.0          0.0          Local-gov
# 14           40.0          0.0            Private
# 15           40.0          0.0            Private
# 16           40.0          0.0          Local-gov
# 17           25.0          0.0            Private
# 18           45.0       2258.0            Private
# 19           40.0          0.0       Self-emp-inc
# 20           40.0          0.0            Private
# 21           40.0          0.0            Private
# 22           40.0          0.0        Federal-gov
# 23           48.0          0.0            Private
# 24           40.0          0.0            Private
# 25           40.0          0.0   Self-emp-not-inc
# 26           15.0          0.0            Private
# 27           40.0          0.0            Private
# 28           12.0          0.0   Self-emp-not-inc
# 29           40.0          0.0            Private
#
# [30 rows x 23 columns]

# %%
# Check the column names of data and data 2
print(list(data.columns))
print(list(data2.columns))
# Out:
# ['id', 'name', 'address', 'age', 'sex', 'date_of_birth']
# ['id', 'name', 'address', 'race', 'marital-status', 'occupation', 'pregnant', 'education-num', 'relationship', 'skewness_glucose', 'mean_glucose', 'capital-gain', 'kurtosis_glucose', 'education', 'fnlwgt', 'class', 'std_glucose', 'income', 'medical_info', 'native-country', 'hours-per-week', 'capital-loss', 'workclass']

# %%
# Count the number of entries in data
len(data)
len(data2)
# Out:
# 3983

# %%
# Check the possible values of columns having less than 50 possible values
def print_col_values(d):
    for c in d.columns:
        l = list(d.drop_duplicates(c)[c])
        if len(l) < 50:
            print("••► " + c + " (" + str(len(l)) + "): " + str(l), end="\n\n")

def print_all_coll_values():
    print("===== Data =====")
    print_col_values(data)
    print("==== Data 2 =====")
    print_col_values(data2)
    
print_all_coll_values()
# Out:
# ===== Data =====
# ••► sex (2): [' Male', ' Female']
#
# ==== Data 2 =====
# ••► race (6): [' White', ' Amer-Indian-Eskimo', ' Black', nan, ' Asian-Pac-Islander', ' Other']
#
# ••► marital-status (8): [' Married-civ-spouse', ' Divorced', ' Never-married', ' Widowed', ' Married-spouse-absent', ' Separated', nan, ' Married-AF-spouse']
#
# ••► occupation (16): [' Prof-specialty', ' Craft-repair', ' Tech-support', ' Transport-moving', ' Adm-clerical', ' Sales', ' Other-service', ' Exec-managerial', ' Machine-op-inspct', ' Protective-serv', ' Farming-fishing', ' Handlers-cleaners', ' ?', ' Priv-house-serv', nan, ' Armed-Forces']
#
# ••► pregnant (7): ['f', 't', 'F', 'FALSE', 'T', nan, 'TRUE']
#
# ••► education-num (17): [12.0, 9.0, 10.0, 13.0, 11.0, 6.0, 16.0, 3.0, 14.0, 8.0, 5.0, 7.0, 4.0, nan, 15.0, 2.0, 1.0]
#
# ••► relationship (7): [' Husband', ' Unmarried', ' Not-in-family', ' Own-child', ' Wife', ' Other-relative', nan]
#
# ••► education (17): [' Assoc-acdm', ' HS-grad', ' Some-college', ' Bachelors', ' Assoc-voc', ' 10th', ' Doctorate', ' 5th-6th', ' Masters', ' 12th', ' 9th', ' 11th', ' 7th-8th', nan, ' Prof-school', ' 1st-4th', ' Preschool']
#
# ••► class (3): [0.0, 1.0, nan]
#
# ••► income (3): [' >50K', ' <=50K', nan]
#
# ••► native-country (40): [' Canada', ' United-States', ' Mexico', ' France', ' Nicaragua', nan, ' Cuba', ' Vietnam', ' ?', ' South', ' India', ' El-Salvador', ' Philippines', ' Guatemala', ' Portugal', ' Jamaica', ' England', ' Germany', ' Ecuador', ' Haiti', ' Japan', ' Puerto-Rico', ' Peru', ' Columbia', ' Iran', ' China', ' Greece', ' Thailand', ' Italy', ' Dominican-Republic', ' Laos', ' Taiwan', ' Ireland', ' Yugoslavia', ' Trinadad&Tobago', ' Cambodia', ' Poland', ' Honduras', ' Hong', ' Scotland']
#
# ••► workclass (9): [' Local-gov', ' Private', ' Self-emp-not-inc', ' Self-emp-inc', ' Federal-gov', ' State-gov', ' ?', ' Without-pay', nan]

# %%
# As we could see above the medical info is in a different format, we need to see 1 of it fully for being able
# to convert it to processable columns
print(data2["medical_info"][0])
# Out:
# {'mean_oxygen':'10.03511706','std_oxygen':'35.25964994','kurtosis_oxygen':'3.851439847','skewness_oxygen':'14.77564968'}

# %%
# Generate the list of columns we need to extract from medical_info
mi_cols = list(dict(eval(data2["medical_info"][0])).keys())
print(mi_cols)
# Out:
# ['mean_oxygen', 'std_oxygen', 'kurtosis_oxygen', 'skewness_oxygen']

# %%
# Extract the 4 data included in the medical_info column and put it to 4 separate columns
for c in mi_cols:
    data2[c] = data2["medical_info"].apply(
        lambda d: 0.0 if str(d) == "nan" else float(dict(eval(str(d)))[c])
    )
data2.head(30)
# Out:
#     id              name                                            address  \
# 0    0        Mike Riley  023 Joseph Estate Suite 799\r\nLake Andrewvill...
# 1    1     Earl Hoffmann            700 Darlene Mill\r\nJackburgh, GA 99369
# 2    2      Lorenzo Mann   56863 Stephen Island\r\nSouth Danielle, NV 40760
# 3    3    Justin Trevino   18446 Pace Junction\r\nNew Christyfurt, SD 32280
# 4    4      Thomas Davis      67753 Wilson Ford\r\nNew Rachelport, NV 50148
# 5    5        Lynn Quist         2232 Flores Ridge\r\nSanchezstad, IL 31455
# 6    6    Roscoe Shelton  6954 Carrillo Shoals Apt. 139\r\nSandersview, ...
# 7    7       Jose Aigner       76756 Ashley Mount\r\nGomezchester, NV 49283
# 8    8      Robert Gerke        820 Mark Drives\r\nMichaelchester, OH 64396
# 9    9     Andre Bennett         25878 Hector Canyon\r\nJerryfurt, AZ 38098
# 10  10       Carson Judy      9121 Steven Lake\r\nNew Christopher, NC 18321
# 11  11       John Reeves           1111 Lisa Roads\r\nMatthewfurt, MN 95571
# 12  12  Kevin Richardson  2847 Tracy Mission Suite 159\r\nLyonschester, ...
# 13  13       William Rao  27786 Perez Mall Suite 843\r\nLake Parkerton, ...
# 14  14      John Whisler  50702 Wu Springs Suite 692\r\nNew Curtis, NE 7...
# 15  15    Andre Mcdonald          448 Miller Ports\r\nLake Samuel, FL 25888
# 16  16   Cedric Matthews         2010 Ross Place\r\nRodriguezport, NH 07286
# 17  17       Roy Colella          7226 Green Tunnel\r\nNorth Lisa, NC 23945
# 18  18        James Chau         21561 Mary Spring\r\nJosephhaven, SD 61945
# 19  19       Jose Fraser       521 Gallegos Islands\r\nWest Brian, KS 37357
# 20  20       Byron Saari      520 Amanda Path\r\nPort Loriborough, AR 42069
# 21  21   Manuel Trombley  1525 Henry Station Suite 174\r\nEast Marcshire...
# 22  22         John Hart                 Unit 0995 Box 2264\r\nDPO AE 51337
# 23  23       Joseph Conn                 PSC 8070, Box 8717\r\nAPO AE 45843
# 24  24  Claude Rodriguez    31740 Jeffrey Falls\r\nPort Faithstad, IA 94696
# 25  25        Jody Nalls  69736 John Shoal Apt. 744\r\nJenkinstown, TN 6...
# 26  26      Edwin Laster  392 Jones Place Suite 295\r\nNorth Jared, IN 0...
# 27  27    Bryon Gallegos         7923 Perez Route\r\nLake Vincent, MO 14843
# 28  28       Raul Sutton  7326 Rodriguez Mountains Apt. 840\r\nAshleyton...
# 29  29      Jesse Seaton                        USS Sanchez\r\nFPO AA 92212
#
#                    race       marital-status          occupation pregnant  \
# 0                 White   Married-civ-spouse      Prof-specialty        f
# 1                 White             Divorced        Craft-repair        f
# 2                 White             Divorced        Craft-repair        t
# 3                 White        Never-married        Tech-support        f
# 4                 White   Married-civ-spouse    Transport-moving        f
# 5                 White             Divorced    Transport-moving        f
# 6                 White   Married-civ-spouse        Adm-clerical        f
# 7                 White             Divorced               Sales        f
# 8                 White   Married-civ-spouse               Sales        F
# 9                 White        Never-married      Prof-specialty        f
# 10                White        Never-married       Other-service        f
# 11                White        Never-married     Exec-managerial        f
# 12                White   Married-civ-spouse   Machine-op-inspct        f
# 13                White   Married-civ-spouse     Protective-serv        f
# 14                White   Married-civ-spouse     Farming-fishing        f
# 15                White             Divorced        Tech-support        f
# 16                White              Widowed     Exec-managerial        f
# 17   Amer-Indian-Eskimo   Married-civ-spouse        Adm-clerical        t
# 18                White        Never-married     Exec-managerial        f
# 19                White   Married-civ-spouse     Exec-managerial        f
# 20                White             Divorced        Adm-clerical        f
# 21                White   Married-civ-spouse       Other-service        f
# 22                White   Married-civ-spouse        Tech-support        f
# 23                White   Married-civ-spouse   Handlers-cleaners        f
# 24                Black             Divorced   Machine-op-inspct        f
# 25                White   Married-civ-spouse               Sales        f
# 26                White        Never-married        Adm-clerical        f
# 27                White   Married-civ-spouse   Handlers-cleaners        f
# 28                White             Divorced        Tech-support        f
# 29                White   Married-civ-spouse   Handlers-cleaners        f
#
#     education-num    relationship  skewness_glucose  ...  income  \
# 0            12.0         Husband          1.605420  ...    >50K
# 1             9.0       Unmarried         10.994893  ...   <=50K
# 2            10.0   Not-in-family         -0.290893  ...   <=50K
# 3            13.0   Not-in-family         13.476089  ...   <=50K
# 4             9.0         Husband          0.680234  ...    >50K
# 5             9.0   Not-in-family          1.315007  ...   <=50K
# 6            13.0         Husband          2.731511  ...   <=50K
# 7            13.0   Not-in-family          2.022478  ...    >50K
# 8            10.0         Husband          0.169639  ...   <=50K
# 9            11.0   Not-in-family          0.743007  ...   <=50K
# 10            9.0       Unmarried          6.810020  ...   <=50K
# 11           10.0       Own-child          0.732969  ...   <=50K
# 12            9.0         Husband         -0.244356  ...   <=50K
# 13           11.0         Husband         -0.317422  ...    >50K
# 14           13.0         Husband         -0.252281  ...   <=50K
# 15           10.0   Not-in-family         -0.034468  ...   <=50K
# 16            9.0   Not-in-family          6.426509  ...   <=50K
# 17           13.0       Own-child         27.688922  ...   <=50K
# 18           13.0   Not-in-family          0.348163  ...    >50K
# 19            9.0         Husband         -0.169973  ...   <=50K
# 20            9.0   Not-in-family          4.229062  ...   <=50K
# 21            6.0         Husband          0.275385  ...   <=50K
# 22            9.0         Husband          0.409075  ...    >50K
# 23            9.0         Husband         -0.403627  ...   <=50K
# 24            9.0       Own-child         -0.275503  ...   <=50K
# 25           13.0         Husband         35.520105  ...    >50K
# 26           10.0       Own-child          0.574901  ...   <=50K
# 27            9.0         Husband         -0.210235  ...   <=50K
# 28           10.0   Not-in-family          0.121619  ...    >50K
# 29           10.0         Husband          1.441155  ...   <=50K
#
#                                          medical_info  native-country  \
# 0   {'mean_oxygen':'10.03511706','std_oxygen':'35....          Canada
# 1   {'mean_oxygen':'7.834448161','std_oxygen':'33....   United-States
# 2   {'mean_oxygen':'3.505852843','std_oxygen':'19....   United-States
# 3   {'mean_oxygen':'83.55351171','std_oxygen':'66....   United-States
# 4   {'mean_oxygen':'2.602842809','std_oxygen':'18....   United-States
# 5   {'mean_oxygen':'4.886287625','std_oxygen':'24....   United-States
# 6   {'mean_oxygen':'1.705685619','std_oxygen':'17....   United-States
# 7   {'mean_oxygen':'2.117056856','std_oxygen':'15....   United-States
# 8   {'mean_oxygen':'5.197324415','std_oxygen':'26....   United-States
# 9   {'mean_oxygen':'0.766722408','std_oxygen':'9.5...   United-States
# 10  {'mean_oxygen':'15.68394649','std_oxygen':'49....   United-States
# 11  {'mean_oxygen':'0.984113712','std_oxygen':'10....   United-States
# 12  {'mean_oxygen':'2.195652174','std_oxygen':'16....          Mexico
# 13  {'mean_oxygen':'2.384615385','std_oxygen':'15....   United-States
# 14  {'mean_oxygen':'3.151337793','std_oxygen':'21....   United-States
# 15  {'mean_oxygen':'5.050167224','std_oxygen':'27....   United-States
# 12        9.396868       98.241129
# 13       10.036317      129.094393
# 14        7.779635       65.685363
# 15        6.059849       38.154786
# 16        2.621427        6.054930
# 17        3.621798       13.174128
# 18        4.103212       16.366380
# 19       13.238378      183.043754
# 20        5.194352       26.092923
# 21       15.096606      271.369362
# 22        5.139543       29.108770
# 23       16.655796      360.430904
# 24        8.622959       78.235336
# 25        1.000055        0.153420
# 26        6.592387       44.233088
# 27        6.880472       52.647388
# 28       11.310935      169.991800
# 29       13.093672      172.173370
#
# [30 rows x 27 columns]

# %%
# Draw graphs about glucouse and oxygen values separately for class = 0 and class = 1 for demonstrating the correlations
def draw_graph(l, d, c):
    graph_data = d[[c, "id"]]
    graph_data.plot.scatter(label=l, x="id", y=c, figsize=(15, 5)).plot()


for gl in [
    "skewness_glucose",
    "mean_glucose",
    "kurtosis_glucose",
    "std_glucose",
    "mean_oxygen",
    "std_oxygen",
    "kurtosis_oxygen",
    "skewness_oxygen",
]:
    for cl in range(2):
        d = data2[data2["class"] == cl]
        draw_graph(gl + " - Class " + str(cl), d, gl)

# %%
#Check descriptive statistics
data2.describe()
# Out:
#                id  education-num  skewness_glucose  mean_glucose  \
# count  3983.00000    3969.000000       3970.000000   3970.000000
# mean   1991.00000      10.105820          4.204384    101.316188
# std    1149.93739       2.617479          9.650541     33.564251
# min       0.00000       1.000000         -1.755332      6.187500
# 25%     995.50000       9.000000         -0.118819     87.812500
# 50%    1991.00000      10.000000          0.373534    110.671875
# 75%    2986.50000      13.000000          2.080266    124.177734
# max    3982.00000      16.000000         68.101622    189.734375
#
#        capital-gain  kurtosis_glucose        fnlwgt        class  std_glucose  \
# count   3974.000000       3972.000000  3.975000e+03  3970.000000  3576.000000
# mean    1021.045294          0.949206  1.906805e+05     0.255919    21.480270
# std     7104.252371          1.607400  1.072447e+05     0.436432  1454.359059
# min        0.000000         -1.641515  1.930200e+04     0.000000 -6180.434729
# 25%        0.000000          0.072000  1.181185e+05     0.000000    39.303373
# 50%        0.000000          0.311577  1.774260e+05     0.000000    45.878359
# 75%        0.000000          0.775953  2.372220e+05     1.000000    50.866252
# max    99999.000000          8.069522  1.268339e+06     1.000000  7510.763110
#
#        hours-per-week  capital-loss  mean_oxygen   std_oxygen  \
# count     3968.000000   3972.000000  3983.000000  3983.000000
# mean        40.413810     89.852467    18.358678    30.976841
# std         12.146992    410.365168    34.711617    22.318882
# min          1.000000      0.000000     0.000000     0.000000
# 25%         40.000000      0.000000     2.047659    14.985995
# 50%         40.000000      0.000000     3.209866    20.427191
# 75%         45.000000      0.000000    12.493729    42.828367
# max         99.000000   4356.000000   217.371238   110.642211
#
#        kurtosis_oxygen  skewness_oxygen
# count      3983.000000      3983.000000
# mean          7.391561        91.140747
# std           4.831313       108.641380
# min          -2.597872        -1.976976
# 25%           3.605114        12.177219
# 50%           7.765440        68.178106
# 75%          10.260328       126.954629
# max          34.539844      1191.000837

# %%
#Check correlation
data2.corr()
# Out:
#                         id  education-num  skewness_glucose  mean_glucose  \
# id                1.000000       0.023416          0.003732     -0.007887
# education-num     0.023416       1.000000         -0.009031     -0.003199
# skewness_glucose  0.003732      -0.009031          1.000000     -0.826373
# mean_glucose     -0.007887      -0.003199         -0.826373      1.000000
# capital-gain     -0.002408       0.123904          0.001938     -0.014922
# kurtosis_glucose  0.001720      -0.002675          0.962056     -0.925739
# fnlwgt           -0.018870      -0.061379         -0.009444      0.021826
# class             0.003652       0.005555          0.680059     -0.774540
# std_glucose      -0.001845      -0.017807          0.010253     -0.027616
# hours-per-week    0.022535       0.132227          0.006267      0.012678
# capital-loss      0.013435       0.078224         -0.005486      0.005045
# mean_oxygen      -0.004581       0.004069          0.550525     -0.541110
# std_oxygen       -0.003292       0.001390          0.556820     -0.556414
# kurtosis_oxygen   0.002513       0.006995         -0.474526      0.469490
# skewness_oxygen   0.003397       0.015867         -0.311117      0.306954
#
#                   capital-gain  kurtosis_glucose    fnlwgt     class  \
# id                   -0.002408          0.001720 -0.018870  0.003652
# education-num         0.123904         -0.002675 -0.061379  0.005555
# skewness_glucose      0.001938          0.962056 -0.009444  0.680059
# mean_glucose         -0.014922         -0.925739  0.021826 -0.774540
# capital-gain          1.000000          0.007281 -0.011007  0.044358
# kurtosis_glucose      0.007281          1.000000 -0.013974  0.787698
# fnlwgt               -0.011007         -0.013974  1.000000 -0.023824
# class                 0.044358          0.787698 -0.023824  1.000000
# std_glucose           0.014430          0.017879 -0.001051  0.004330
# hours-per-week        0.057342         -0.001052 -0.062134 -0.007610
# capital-loss         -0.031535         -0.007551 -0.005328 -0.005261
# mean_oxygen          -0.008520          0.594049 -0.015537  0.514376
# std_oxygen            0.002001          0.616980 -0.016870  0.641619
# kurtosis_oxygen       0.003613         -0.525496  0.023570 -0.556507
# skewness_oxygen       0.000179         -0.346084  0.026052 -0.391951
#
#                   std_glucose  hours-per-week  capital-loss  mean_oxygen  \
# id                  -0.001845        0.022535      0.013435    -0.004581
# education-num       -0.017807        0.132227      0.078224     0.004069
# skewness_glucose     0.010253        0.006267     -0.005486     0.550525
# mean_glucose        -0.027616        0.012678      0.005045    -0.541110
# capital-gain         0.014430        0.057342     -0.031535    -0.008520
# kurtosis_glucose     0.017879       -0.001052     -0.007551     0.594049
# fnlwgt              -0.001051       -0.062134     -0.005328    -0.015537
# class                0.004330       -0.007610     -0.005261     0.514376
# std_glucose          1.000000        0.006073     -0.017251     0.023268
# hours-per-week       0.006073        1.000000      0.051385     0.008126
# capital-loss        -0.017251        0.051385      1.000000     0.031288
# mean_oxygen          0.023268        0.008126      0.031288     1.000000
# std_oxygen           0.008483       -0.002563      0.016550     0.801483
# kurtosis_oxygen     -0.009952        0.000573     -0.014229    -0.653326
# skewness_oxygen     -0.016300       -0.001695     -0.006590    -0.393965
#
#                   std_oxygen  kurtosis_oxygen  skewness_oxygen
# id                 -0.003292         0.002513         0.003397
# education-num       0.001390         0.006995         0.015867
# skewness_glucose    0.556820        -0.474526        -0.311117
# mean_glucose       -0.556414         0.469490         0.306954
# capital-gain        0.002001         0.003613         0.000179
# kurtosis_glucose    0.616980        -0.525496        -0.346084
# fnlwgt             -0.016870         0.023570         0.026052
# class               0.641619        -0.556507        -0.391951
# std_glucose         0.008483        -0.009952        -0.016300
# hours-per-week     -0.002563         0.000573        -0.001695
# capital-loss        0.016550        -0.014229        -0.006590
# mean_oxygen         0.801483        -0.653326        -0.393965
# std_oxygen          1.000000        -0.825101        -0.596467
# kurtosis_oxygen    -0.825101         1.000000         0.916746
# skewness_oxygen    -0.596467         0.916746         1.000000

# %%
# Plot charts with glucose and oxygen data related to the disease classification for demonstrating the correlation
sea.scatterplot(data2.mean_glucose, data2.mean_oxygen, hue=data2['class']).plot()
# Out:
# []

# %%
sea.scatterplot(data2.std_glucose, data2.std_oxygen, hue=data2['class']).plot()
# Out:
# []

# %%
sea.scatterplot(data2.skewness_glucose, data2.skewness_oxygen, hue=data2['class']).plot()
# Out:
# []

# %%
sea.scatterplot(data2.kurtosis_glucose, data2.kurtosis_oxygen, hue=data2['class']).plot()
# Out:
# []

# %%
# Find name duplicates in data
data[data.duplicated(["name"])]
# Out:
# Empty DataFrame
# Columns: [id, name, address, age, sex, date_of_birth]
# Index: []

# %%
# Find name duplicates in data2
data2[data2.duplicated(["name"])]
# Out:
#         id                name  \
# 219    219       Maurice Riley
# 474    474    Raymundo Marceau
# 853    853  Jackson Moorehouse
# 1010  1010          Adam Perry
# 1355  1355    Michael Atchison
# 1382  1382       Thomas Porter
# 1568  1568      Michael Barnum
# 1588  1588         Raul Vernon
# 1957  1957      William Valdez
# 1987  1987         David Amaya
# 2051  2051       Anthony Sauer
# 2149  2149      Richard Stokes
# 2155  2155             Mike Rm
# 2187  2187       Roy Wiederwax
# 2233  2233           John Cuff
# 2345  2345           Jay Wells
# 2376  2376       Frank Holland
# 2457  2457         Clark Smith
# 2471  2471      James Limerick
# 2474  2474      Vincent Farmer
# 2488  2488       Richard Keith
# 2509  2509      Darrell Dickey
# 2600  2600       Willie Gerace
# 2622  2622    Napoleon Branner
# 2719  2719      Wallace Street
# 2722  2722        Luis Coulter
# 2831  2831         Wesley Srey
# 2841  2841       Alex Williams
# 2903  2903           Gary High
# 2947  2947      Mark Partridge
# 2977  2977    Thaddeus Mackerl
# 3051  3051     Michael Kennedy
# 3101  3101      Allen Brickley
# 3120  3120       Dana Guajardo
# 3221  3221        Chong Carter
# 3276  3276          Paul Bryan
# 3280  3280    Robert Shoemaker
# 3336  3336       Bruce Daniels
# 3410  3410       Edmund Watson
# 3463  3463          Bobby Hawk
# 3492  3492       Francis Duong
# 3677  3677          Paul Karas
# 3708  3708         John Merkle
# 3769  3769     Nicholas Reimer
# 3773  3773        Edgar Nelson
# 3807  3807         Joel Cramer
# 3823  3823       Curtis Benson
# 3845  3845      Terrance Smith
# 3959  3959         Edward Hood
# 3979  3979      Bernard Hilser
#
#                                                 address                 race  \
# 219     58487 Schneider Street\r\nGriffinfurt, RI 56689                White
# 474          993 Heather View\r\nCarolynhaven, UT 99182                White
# 853           621 William Skyway\r\nPort Mark, LA 44554                White
# 1010            02726 Hale Lane\r\nLynchmouth, HI 33466                White
# 3845             30338 Miller Coves\r\nLetown, TN 69998                White
# 3959  87749 Angela Glens Apt. 048\r\nNew Christopher...                White
# 3979            11425 Taylor Fall\r\nMikeside, SC 82575                White
#
#            marital-status          occupation pregnant  education-num  \
# 219              Divorced   Machine-op-inspct        f            9.0
# 474         Never-married        Adm-clerical        f            9.0
# 853    Married-civ-spouse        Adm-clerical      NaN            NaN
# 1010              Widowed        Adm-clerical        f           10.0
# 1355   Married-civ-spouse               Sales        f            NaN
# 1382   Married-civ-spouse   Machine-op-inspct        f            9.0
# 1568   Married-civ-spouse     Exec-managerial        f            NaN
# 1588        Never-married                 NaN        f            9.0
# 1957   Married-civ-spouse     Exec-managerial        f            9.0
# 1987   Married-civ-spouse                 NaN        f            9.0
# 2051        Never-married     Farming-fishing        f           10.0
# 2149   Married-civ-spouse     Protective-serv        f           13.0
# 2155             Divorced        Craft-repair      NaN            9.0
# 2187             Divorced      Prof-specialty        f           15.0
# 2233   Married-civ-spouse       Other-service        f            7.0
# 2345             Divorced       Other-service      NaN           11.0
# 2376             Divorced                 NaN    FALSE            9.0
# 2457   Married-civ-spouse                   ?        f           13.0
# 2471   Married-civ-spouse        Craft-repair        f           10.0
# 2474        Never-married      Prof-specialty        f           16.0
# 2488             Divorced     Exec-managerial        f           11.0
# 2509   Married-civ-spouse        Adm-clerical        f            9.0
# 2600             Divorced     Farming-fishing        f            NaN
# 2622   Married-civ-spouse    Transport-moving        f           10.0
# 2719   Married-civ-spouse   Handlers-cleaners        f           10.0
# 2722              Widowed     Exec-managerial      NaN            NaN
# 2831   Married-civ-spouse   Handlers-cleaners        f            9.0
# 2841   Married-civ-spouse        Craft-repair        f           11.0
# 2903                  NaN       Other-service        f            7.0
# 2947        Never-married   Handlers-cleaners        f            NaN
# 2977              Widowed        Craft-repair      NaN            9.0
# 3051   Married-civ-spouse        Tech-support        f           14.0
# 3101   Married-civ-spouse       Other-service        f            NaN
# 3120                  NaN     Exec-managerial        f            9.0
# 3221   Married-civ-spouse   Machine-op-inspct        f            9.0
# 3276   Married-civ-spouse        Craft-repair        f            6.0
# 3280   Married-civ-spouse               Sales        f            9.0
# 3336   Married-civ-spouse      Prof-specialty        f           14.0
# 3410   Married-civ-spouse     Exec-managerial        f           16.0
# 3463   Married-civ-spouse        Tech-support        f           12.0
# 3492   Married-civ-spouse    Transport-moving        f            9.0
# 3677   Married-civ-spouse     Exec-managerial        f           13.0
# 3708             Divorced               Sales      NaN           11.0
# 3769        Never-married   Handlers-cleaners        f            7.0
# 3773        Never-married      Prof-specialty        f           13.0
# 3807        Never-married      Prof-specialty        f           10.0
# 3823        Never-married       Other-service        f           11.0
# 3845        Never-married                 NaN    FALSE            9.0
# 3959   Married-civ-spouse    Transport-moving        f            7.0
# 3979        Never-married               Sales        f            9.0
#
#         relationship  skewness_glucose  ...  income  \
# 219              NaN          0.220759  ...   <=50K
# 474        Own-child          0.912863  ...   <=50K
# 853          Husband          0.251593  ...    >50K
# 1010       Unmarried               NaN  ...     NaN
# 1355         Husband          0.765886  ...    >50K
# 1382         Husband               NaN  ...     NaN
# 1568         Husband          0.796410  ...    >50K
# 1588   Not-in-family               NaN  ...   <=50K
# 1957         Husband          0.284425  ...   <=50K
# 1987         Husband         -0.724337  ...   <=50K
# 2051       Own-child         12.393969  ...   <=50K
# 2149         Husband         -0.359568  ...   <=50K
# 2155             NaN               NaN  ...    >50K
# 2187   Not-in-family          0.013982  ...     NaN
# 2233            Wife          0.182466  ...   <=50K
# 2345             NaN          0.060912  ...   <=50K
# 2376       Unmarried          0.899047  ...   <=50K
# 2457         Husband          5.185332  ...    >50K
# 2471         Husband          0.210648  ...     NaN
# 2474   Not-in-family          0.598783  ...   <=50K
# 2488       Own-child         -0.261603  ...   <=50K
# 2509            Wife         -0.365370  ...   <=50K
# 2600       Unmarried          0.120915  ...   <=50K
# 2622         Husband          5.474290  ...   <=50K
# 2719         Husband         -0.252255  ...    >50K
# 2722   Not-in-family          0.936741  ...     NaN
# 2831             NaN         -0.564141  ...   <=50K
# 2841         Husband          0.263672  ...     NaN
# 2903             NaN         30.672768  ...     NaN
# 2947             NaN          5.557122  ...   <=50K
# 2977   Not-in-family          0.689558  ...    >50K
# 3051         Husband          0.087649  ...    >50K
# 3101         Husband          5.954116  ...   <=50K
# 3120             NaN          1.690689  ...   <=50K
# 3221         Husband               NaN  ...   <=50K
# 3276         Husband         11.137020  ...   <=50K
# 3280         Husband         -0.512646  ...   <=50K
# 3336         Husband               NaN  ...    >50K
# 3410         Husband          0.484808  ...    >50K
# 3463            Wife               NaN  ...     NaN
# 3492             NaN         -0.336344  ...   <=50K
# 3677         Husband          1.189220  ...   <=50K
# 3708   Not-in-family               NaN  ...   <=50K
# 3769   Not-in-family         13.105819  ...   <=50K
# 3773   Not-in-family         -0.320280  ...   <=50K
# 3807             NaN               NaN  ...   <=50K
# 3823             NaN          0.213605  ...   <=50K
# 3845       Own-child          0.144186  ...   <=50K
# 3959             NaN          1.532027  ...   <=50K
# 3979       Own-child          0.259229  ...   <=50K
#
#                                            medical_info  native-country  \
# 219   {'mean_oxygen':'2.526755853','std_oxygen':'14....   United-States
# 474   {'mean_oxygen':'2.034280936','std_oxygen':'15....   United-States
# 853   {'mean_oxygen':'2.581103679','std_oxygen':'16....   United-States
# 1010                                                NaN   United-States
# 1355  {'mean_oxygen':'2.956521739','std_oxygen':'15....   United-States
# 1382  {'mean_oxygen':'91.55183946','std_oxygen':'102...             NaN
# 1568                                                NaN             NaN
# 1588  {'mean_oxygen':'5.973244147000001','std_oxygen...             NaN
# 1957  {'mean_oxygen':'6.505016722000001','std_oxygen...   United-States
# 1987  {'mean_oxygen':'2.843645485','std_oxygen':'20....   United-States
# 2051                                                NaN             NaN
# 2149  {'mean_oxygen':'4.122909699','std_oxygen':'23....         England
# 2155  {'mean_oxygen':'1.429765886','std_oxygen':'11....             NaN
# 2187  {'mean_oxygen':'2.987458194','std_oxygen':'18....   United-States
# 2233  {'mean_oxygen':'0.837792642','std_oxygen':'12....   United-States
# 2345  {'mean_oxygen':'6.269230769','std_oxygen':'29....   United-States
# 2376  {'mean_oxygen':'2.315217391','std_oxygen':'14....   United-States
# 2457  {'mean_oxygen':'5.619565217000001','std_oxygen...   United-States
# 2471                                                NaN             NaN
# 2474  {'mean_oxygen':'1.97993311','std_oxygen':'13.1...   United-States
# 2488                                                NaN   United-States
# 2509  {'mean_oxygen':'4.759197324','std_oxygen':'23....   United-States
# 2600  {'mean_oxygen':'2.046822742','std_oxygen':'12....   United-States
# 2622  {'mean_oxygen':'21.51839465','std_oxygen':'54....   United-States
# 2719  {'mean_oxygen':'3.772575251','std_oxygen':'19....   United-States
# 2722  {'mean_oxygen':'1.876254181','std_oxygen':'11....   United-States
# 2831  {'mean_oxygen':'11.44230769','std_oxygen':'43....   United-States
# 2841  {'mean_oxygen':'2.658862876','std_oxygen':'15....   United-States
# 2903  {'mean_oxygen':'139.5928094','std_oxygen':'80....   United-States
# 2947  {'mean_oxygen':'12.61622074','std_oxygen':'42....   United-States
# 2977  {'mean_oxygen':'1.5802675590000002','std_oxyge...   United-States
# 3051  {'mean_oxygen':'3.16722408','std_oxygen':'22.3...     Philippines
# 3101                                                NaN   United-States
# 3120  {'mean_oxygen':'4.434782609','std_oxygen':'22....   United-States
# 3221  {'mean_oxygen':'4.1479933110000005','std_oxyge...   United-States
# 3276  {'mean_oxygen':'34.64548495','std_oxygen':'69....   United-States
# 3280  {'mean_oxygen':'1.239130435','std_oxygen':'11....   United-States
# 3336  {'mean_oxygen':'2.397993311','std_oxygen':'14....   United-States
# 3410  {'mean_oxygen':'0.673913043','std_oxygen':'10....   United-States
# 3463  {'mean_oxygen':'19.627090300000006','std_oxyge...   United-States
# 3492  {'mean_oxygen':'2.297658863','std_oxygen':'14....   United-States
# 3677  {'mean_oxygen':'1.475752508','std_oxygen':'11....   United-States
# 3708  {'mean_oxygen':'2.050167224','std_oxygen':'20....   United-States
# 3769  {'mean_oxygen':'95.91220736','std_oxygen':'66....   United-States
# 3773  {'mean_oxygen':'2.119565217','std_oxygen':'13....   United-States
# 3807  {'mean_oxygen':'3.660535117','std_oxygen':'24....   United-States
# 3823  {'mean_oxygen':'0.488294314','std_oxygen':'9.5...   United-States
# 3845  {'mean_oxygen':'1.394648829','std_oxygen':'11....   United-States
# 3959  {'mean_oxygen':'3.712374582','std_oxygen':'23....   United-States
# 3979  {'mean_oxygen':'1.5903010030000002','std_oxyge...   United-States
#
#      hours-per-week  capital-loss          workclass  mean_oxygen  std_oxygen  \
# 219            40.0           NaN            Private     2.526756   14.287719
# 474            40.0           0.0            Private     2.034281   15.260820
# 853             NaN           0.0            Private     2.581104   16.575941
# 1010           40.0           0.0                NaN     0.000000    0.000000
# 1355           45.0        1902.0            Private     2.956522   15.094622
# 1382           40.0           0.0            Private    91.551839  102.500925
# 1568            NaN           0.0            Private     0.000000    0.000000
# 1588           40.0           0.0            Private     5.973244   31.325766
# 1957           40.0           0.0       Self-emp-inc     6.505017   31.948524
# 1987           50.0           0.0            Private     2.843645   20.990955
# 2051           40.0           0.0                NaN     0.000000    0.000000
# 3051        7.591025       59.745587
# 3101        0.000000        0.000000
# 3120        5.939747       39.781374
# 3221        7.203474       50.075911
# 3276        1.663044        1.066221
# 3280       13.708762      232.700512
# 3336        8.826906      102.784830
# 3410       20.264707      453.471408
# 3463        2.890254        7.578930
# 3492       11.025123      150.117636
# 3677       14.960063      281.483145
# 3708       10.596441      113.930354
# 3769        0.484440       -0.438687
# 3773       10.298703      138.697795
# 3807        7.247692       54.052641
# 3823       22.479813      538.015822
# 3845       13.085234      223.421130
# 3959        8.139562       70.774285
# 3979       11.682068      158.766088
#
# [50 rows x 27 columns]

# %%
# Check the difference between 2 entries having the same name
name = list(data2[data2.duplicated(["name"])]["name"])[0]
data2[data2["name"] == name]
# Out:
#       id           name                                          address  \
# 92    92  Maurice Riley  58487 Schneider Street\r\nGriffinfurt, RI 56689
# 219  219  Maurice Riley  58487 Schneider Street\r\nGriffinfurt, RI 56689
#
#        race marital-status          occupation pregnant  education-num  \
# 92    White       Divorced   Machine-op-inspct        f            9.0
# 219   White       Divorced   Machine-op-inspct        f            9.0
#
#     relationship  skewness_glucose  ...  income  \
# 92     Own-child          0.220759  ...   <=50K
# 219          NaN          0.220759  ...   <=50K
#
#                                           medical_info  native-country  \
# 92                                                 NaN             NaN
# 219  {'mean_oxygen':'2.526755853','std_oxygen':'14....   United-States
#
#     hours-per-week  capital-loss  workclass  mean_oxygen std_oxygen  \
# 92            40.0           0.0        NaN     0.000000   0.000000
# 219           40.0           NaN    Private     2.526756  14.287719
#
#     kurtosis_oxygen skewness_oxygen
# 92          0.00000         0.00000
# 219         8.42785       100.93002
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Predspracovanie (max. 18b)
#
# Na základe identifikovaných problémov v dátach a návrhu ich riešenia v predchádzajúcej fáze treba zrealizovať predspracovanie. Výsledkom by mala byť upravená dátová sada (vo formáte `csv`) vo vhodnom tvare pre strojové učenie. To znamená, že jedno pozorovanie musí byť opísané jedným riadkom tabuľky; zároveň, keďže v tretej fáze budeme pracovať s algoritmom, ktorého implementácia podporuje len numerické dáta, bude potrebné všetky nenumerické atribúty transformovať na numerické. Napokon, keďže sa predspracovaním mohol zmeniť tvar a charakteristiky dát (počet atribútov, distribúcie hodnôt a pod.), treba znovu zrealizovať podstatné časti prieskumnej analýzy. Významnú časť hodnotenia bude predstavovať znovupoužiteľnosť (replikovateľnosť) predspracovania.
#
# V tejto fáze sa od vás očakáva:
# - **Integrácia dát a prípadná deduplikácia záznamov (4b).** Výsledkom by mala byť jednotná tabuľková reprezentácia dát, ktorá bude predstavovať vstup pre ďalšie spracovanie a (v 3. fáze) strojové učenie.
# - **Realizácia krokov predspracovania dát a ich zdokumentovanie (5b).**
#   - Pri riešení chýbajúcich hodnôt vyskúšajte rôzne stratégie (očakáva sa vyskúšanie minimálne dvoch stratégií, pričom aspoň jedna z nich musí byť zvolená z posledných troch menovaných):
#     - nahradenie chýbajúcej hodnoty mediánom
#     - nahradenie chýbajúcej hodnoty priemerom
#     - nahradenie chýbajúcej hodnoty pomerom ku korelovanému atribútu
#     - nahradenie chýbajúcej hodnoty priemerom segmentu
#     - nahradenie chýbajúcej hodnoty pomocou lineárnej regresie
#     - nahradenie chýbajúcej hodnoty pomocou algoritmu k-najbližších susedov
#   - Podobne postupujte aj pri riešení vychýlených (odľahlých) hodnôt, pričom vyskúšajte aspoň dve  zo stratégií uvedených nižšie:
#     - odstránenie vychýlených (odľahlých) pozorovaní
#     - nahradenie vychýlenej hodnoty hraničnými hodnotami rozdelenia (5 percentilom, resp. 95 percentilom)
#     - transformácia atribútu s vychýlenými hodnotami pomocou zvolenej funkcie (logaritmus, odmocnina a pod.)
# - **Znovupoužiteľnosť predspracovania (5b).** Upravte váš kód realizujúci predspracovanie trénovacej množiny tak, aby ho bolo možné bez ďalších úprav znovupoužiť na predspracovanie validačnej, resp. testovacej množiny (ich predspracovanie sa pritom v tej fáze nevyžaduje, odovzdaný kód v `Jupyter Notebooku` na to však musí byť pripravený). Očakáva sa preto, že bude predspracovanie realizované pomocou funkcií alebo využijete možnosti knižnice `sklearn.pipeline`. Častým problémom býva využitie informácií, ktoré nie sú dostupné v čase zbierania údajov (napr. štatistické informácie o celej testovacej sade pri spracovaní trénovacích údajov alebo aj pri spracovaní jednotlivých pozorovaní z testovacej sady), čím môžete do trénovania zaniesť znalosť z validačnej alebo testovacej množiny; vaše riešenie toto musí ošetrovať.
# - **Opätovná realizácia podstatných častí prieskumnej analýzy (4b).** V rámci nej by ste mali vedieť zodpovedať na otázku, ako sa zmenili distribúcie hodnôt po realizácii krokov predspracovania (t. j. treba ju realizovať len tam, kde vaším predspracovaním došlo k nejakým zmenám).
#
# Správa sa odovzdáva v 9. týždni semestra na cvičení (dvojica svojmu cvičiacemu odprezentuje vykonané predspracovanie v `Jupyter Notebooku`). Následne správu elektronicky odovzdá jeden člen z  dvojice do systému AIS do **nedele 24.11.2019 do 23:59**.
#
#
# # Opätovná realizácia podstatných častí prieskumnej analýzy
#
# **Všeobecné**
# - Niektoré stĺpce obsahovali medzeru pred hodnotou. Tieto medzeri sme odstránili
#
# - Spájanie riadkov v prípade duplicitných záznamov: pokiaľ záznam obsahuje “nan” alebo “?”, doplní sa z iného záznamu. Pokiaľ oba záznamy obsahujú hodnotu v stĺpci, numerické hodnoty zapíšu priemer hodnôt a nenumerické hodnoty vyberú prvú z možností
#
# **Date_of_birth**
# - Dátum je spracovaný do formátu yyyy-mm-dd. Boli z neho odstránené časy narodenia. „/“ bola nahradená „-“. Rok narodenia zapísaný v tvare napr. 68 (1968) bol podľa veku upravený na požadovaný formát.
#
# **Age**
# - Z upravených dátumov narodenia sa dopočítal chýbajúci vek
#
# **Pregnant**
# - Hodnoty boli zjednotené na „True“ a „False“
#
# **Education_num**
# - „nan“ hodnoty boli nahradené mediánom
#
# **Income**
# - Zjednotené na 2 hodnoty “>50K“ a „<=50K” pomocou mediánu
#
# **Class**
# - Hodnoty sme zmenili na integer a obsahujú len hodnoty “1” a “0”
#
# **Std_glucose**
# - Chýbajúce hodnoty boli dopočítané priemerom. Odľahlé hodnoty sme nahradili hraničnou hodnotou rozdelenia  - 95 percentilom a 5 percentilom
#
# **Skewness_oxygen**
# - Chýbajúce hodnoty boli dopočítané priemerom. Odľahlé hodnoty sme nahradili hraničnou hodnotou rozdelenia  - 95 percentilom
#
# **mean_oxygen**
# - Chýbajúce hodnoty boli dopočítané priemerom. Odľahlé hodnoty sme nahradili logaritmom hodnôt.
#
# **Skewness_glucose**
# - Chýbajúce hodnoty boli dopočítané priemerom. Odľahlé hodnoty sme nahradili hraničnou hodnotou rozdelenia  - 95 percentilom
#
# **Std_oxygen, mean_glucose, kurtosis_glucose, kurtosis_oxygen**
# - Chýbajúce hodnoty boli nahradené priemerom
#
# **Capital_loss, capital_gain, fnlwgt, hour-per-week**
# - Chýbajúce hodnoty boli nahradené mediánom

# %%
# Remove time from the date_of_birth
data["date_of_birth"] = data["date_of_birth"].str.split(" ", expand=True)[0]
data.head(30)
# Out:
#     id                  name  \
# 0    0       Roscoe Bohannon
# 1    1          Ernest Kline
# 2    2       Harold Hendriks
# 3    3        Randy Baptiste
# 4    4       Anthony Colucci
# 5    5          Ronald Lange
# 6    6         Boyd Eiselein
# 7    7         Raymond Smith
# 8    8         Harold Miller
# 9    9  Charles Czachorowski
# 10  10       Robert Grantham
# 11  11              Joel Lam
# 12  12            Irving Gil
# 13  13        Terry Reynolds
# 14  14      Kurt Littlefield
# 15  15          Andy Grayson
# 16  16       Chauncey Suarez
# 17  17        Wallace Street
# 18  18       Daniel Crossman
# 19  19            Steve Ripp
# 20  20       George Hairston
# 21  21        Jeffrey Taylor
# 22  22           David Mealy
# 23  23        Garfield Bowen
# 24  24      Thaddeus Mackerl
# 25  25           Gerald Pack
# 26  26       Jonathon Nemith
# 27  27           Roger Groce
# 28  28          Harold Odowd
# 29  29       Stanley Forrest
#
#                                               address   age      sex  \
# 0   7183 Osborne Ways Apt. 651\r\nEast Andrew, OH ...  60.0     Male
# 1   391 Ball Road Suite 961\r\nFlowersborough, IN ...  52.0     Male
# 2      8702 Vincent Square\r\nNew Jerryfurt, CO 30614  60.0     Male
# 3      2751 Harris Crossroad\r\nWest Ashley, CA 30311  39.0     Male
# 4   904 Robert Cliffs Suite 186\r\nWest Kyle, CO 7...  49.0     Male
# 5         30973 Martinez Shores\r\nJameston, CA 70245  46.0     Male
# 6   29941 Christopher Curve Apt. 682\r\nRaychester...  54.0   Female
# 7   53487 Scott Extensions Apt. 824\r\nMccartytown...  67.0     Male
# 8   8514 Elizabeth Crescent\r\nWest Joseland, GA 4...  52.0     Male
# 9   6798 Wagner Locks Suite 377\r\nLake Brenda, DC...  30.0     Male
# 10            822 Adams Plains\r\nNew Karen, AK 92114  38.0     Male
# 11  61296 Reginald Rapids Suite 783\r\nWest Timoth...  62.0     Male
# 12  90757 Amanda Views Suite 604\r\nPort Paul, TX ...  56.0     Male
# 13  0019 Jensen Land Apt. 513\r\nPort Timothyville...  76.0     Male
# 14       822 Wilson Meadow\r\nMitchellmouth, RI 05935   NaN     Male
# 15            2573 Ryan Mission\r\nShortton, DC 01129  67.0     Male
# 16      481 Wilson Prairie\r\nKimberlymouth, LA 20064  46.0   Female
# 17          9909 John Creek\r\nEast Heather, NY 31266  44.0     Male
# 18   74669 Robles Drive\r\nPort Madisonbury, LA 63565  45.0     Male
# 19           7629 Ramos Knoll\r\nOwensmouth, NC 34420  54.0   Female
# 20      18356 Benjamin Roads\r\nSouth Nancy, NJ 58120  51.0     Male
# 21                           USNV Kim\r\nFPO AA 96043  39.0   Female
# 22          0873 Diaz Village\r\nSandrastad, DE 05796  53.0     Male
# 23   3678 Gloria Pine Apt. 652\r\nKevinfort, LA 80839  54.0     Male
# 24  8122 Jessica Knolls Apt. 880\r\nDakotafurt, WV...  47.0     Male
# 25       6146 Roman Shores\r\nNew Christine, OR 28920  55.0     Male
# 26            875 David Road\r\nPhillipfort, NC 26174  51.0     Male
# 27          781 Berry Spring\r\nTravismouth, NJ 11603  46.0   Female
# 28  7842 Curtis Vista Apt. 188\r\nLake Samuelburgh...  55.0     Male
# 29  9532 Jesse Roads Suite 253\r\nNorth Toni, NC 7...  52.0     Male
#
#    date_of_birth
# 0     1959-09-26
# 1     1966-10-28
# 2     1959-06-16
# 3     1980-09-09
# 4     1970-02-22
# 5     1973-09-25
# 6     1964-10-31
# 7     1952-07-23
# 8     1967-06-28
# 9     1988-11-07
# 10    1981-05-01
# 11    1957-08-10
# 12    16/11/1962
# 13    21/04/1943
# 14    1985-11-03
# 15    1952-08-06
# 16    1973-06-27
# 17    1975-01-10
# 18    1973-12-24
# 19    1965-05-06
# 20    1968-09-07
# 21    1980-06-11
# 22    1966-10-21
# 23    1965/04/25
# 24    1972-07-10
# 25    1963-12-19
# 26    1968-03-02
# 27    1972-12-11
# 28    1963-12-06
# 29    1967-09-04

# %%
# Replace '/' characters to '-' characters in date_of_birth
data["date_of_birth"] = data["date_of_birth"].str.replace("/", "-")
data.head(30)
# Out:
#     id                  name  \
# 0    0       Roscoe Bohannon
# 1    1          Ernest Kline
# 2    2       Harold Hendriks
# 3    3        Randy Baptiste
# 4    4       Anthony Colucci
# 5    5          Ronald Lange
# 6    6         Boyd Eiselein
# 7    7         Raymond Smith
# 8    8         Harold Miller
# 9    9  Charles Czachorowski
# 10  10       Robert Grantham
# 11  11              Joel Lam
# 12  12            Irving Gil
# 13  13        Terry Reynolds
# 14  14      Kurt Littlefield
# 15  15          Andy Grayson
# 16  16       Chauncey Suarez
# 17  17        Wallace Street
# 18  18       Daniel Crossman
# 19  19            Steve Ripp
# 20  20       George Hairston
# 21  21        Jeffrey Taylor
# 22  22           David Mealy
# 23  23        Garfield Bowen
# 24  24      Thaddeus Mackerl
# 25  25           Gerald Pack
# 26  26       Jonathon Nemith
# 27  27           Roger Groce
# 28  28          Harold Odowd
# 29  29       Stanley Forrest
#
#                                               address   age      sex  \
# 0   7183 Osborne Ways Apt. 651\r\nEast Andrew, OH ...  60.0     Male
# 1   391 Ball Road Suite 961\r\nFlowersborough, IN ...  52.0     Male
# 2      8702 Vincent Square\r\nNew Jerryfurt, CO 30614  60.0     Male
# 3      2751 Harris Crossroad\r\nWest Ashley, CA 30311  39.0     Male
# 4   904 Robert Cliffs Suite 186\r\nWest Kyle, CO 7
# 18    1973-12-24
# 19    1965-05-06
# 20    1968-09-07
# 21    1980-06-11
# 22    1966-10-21
# 23    1965-04-25
# 24    1972-07-10
# 25    1963-12-19
# 26    1968-03-02
# 27    1972-12-11
# 28    1963-12-06
# 29    1967-09-04

# %%
# Fix non-numeric age values
def fix_age(age):
    try:
        return int(age)
    except:
        return 0


data["age"] = data["age"].apply(fix_age)

# %%
# Check people with age greater than 90,
# to know how to properly convert 2 digit date_of_birth year field values to 4 digit one
data[data["age"] > 90]
# Out:
#         id               name  \
# 1458  1458       Edward Freas
# 2195  2195    Richard Alvarez
# 2865  2865  Charles Gillespie
#
#                                                 address  age    sex  \
# 1458       3415 Davis Centers\r\nLake Matthew, WA 20714   93   Male
# 2195  92341 Matthew Trail Suite 673\r\nEast Janet, I...   97   Male
# 2865  62025 Michael Turnpike\r\nSouth Stephaniemouth...   99   Male
#
#      date_of_birth
# 1458    27-03-1926
# 2195    1922-09-05
# 2865    1920-03-03

# %%
# Fix the date format in the date_of_birth, make it consistently being yyyy-mm-dd
def fix_date(date):
    s = date.split("-")
    if (
        len(s[0]) == 4
    ):  # Don't need to fix anything if the first field is a 4 digit year number
        return date
    if len(s[2]) == 4:  # Replace dd-mm-yyyy format to yyyy-mm-dd format
        return s[2] + "-" + s[1] + "-" + s[0]
    # Replace yy-mm-dd format to yyyy-mm-dd format
    #
    # If the last 2 digit of the 4 digit year field is bigger than 20,
    # then we expect a date of birth between 1921 and 1999, otherwise between 2000 and 2020,
    # because we have verified earlier that we don't have people older than 90 years old in such date format
    if int(s[0]) > 20:
        return "19" + s[0] + "-" + s[1] + "-" + s[2]
    else:
        return "20" + s[0] + "-" + s[1] + "-" + s[2]
    return date


data["date_of_birth"] = data["date_of_birth"].apply(fix_date)
data.head(30)
# Out:
#     id                  name  \
# 0    0       Roscoe Bohannon
# 1    1          Ernest Kline
# 2    2       Harold Hendriks
# 3    3        Randy Baptiste
# 4    4       Anthony Colucci
# 5    5          Ronald Lange
# 6    6         Boyd Eiselein
# 7    7         Raymond Smith
# 8    8         Harold Miller
# 9    9  Charles Czachorowski
# 10  10       Robert Grantham
# 11  11              Joel Lam
# 12  12            Irving Gil
# 13  13        Terry Reynolds
# 14  14      Kurt Littlefield
# 15  15          Andy Grayson
# 16  16       Chauncey Suarez
# 17  17        Wallace Street
# 18  18       Daniel Crossman
# 19  19            Steve Ripp
# 20  20       George Hairston
# 21  21        Jeffrey Taylor
# 22  22           David Mealy
# 23  23        Garfield Bowen
# 24  24      Thaddeus Mackerl
# 25  25           Gerald Pack
# 26  26       Jonathon Nemith
# 27  27           Roger Groce
# 28  28          Harold Odowd
# 29  29       Stanley Forrest
#
#                                               address  age      sex  \
# 0   7183 Osborne Ways Apt. 651\r\nEast Andrew, OH ...   60     Male
# 1   391 Ball Road Suite 961\r\nFlowersborough, IN ...   52     Male
# 2      8702 Vincent Square\r\nNew Jerryfurt, CO 30614   60     Male
# 3      2751 Harris Crossroad\r\nWest Ashley, CA 30311   39     Male
# 4   904 Robert Cliffs Suite 186\r\nWest Kyle, CO 7...   49     Male
# 5         30973 Martinez Shores\r\nJameston, CA 70245   46     Male
# 6   29941 Christopher Curve Apt. 682\r\nRaychester...   54   Female
# 7   53487 Scott Extensions Apt. 824\r\nMccartytown...   67     Male
# 8   8514 Elizabeth Crescent\r\nWest Joseland, GA 4...   52     Male
# 9   6798 Wagner Locks Suite 377\r\nLake Brenda, DC...   30     Male
# 10            822 Adams Plains\r\nNew Karen, AK 92114   38     Male
# 11  61296 Reginald Rapids Suite 783\r\nWest Timoth...   62     Male
# 12  90757 Amanda Views Suite 604\r\nPort Paul, TX ...   56     Male
# 13  0019 Jensen Land Apt. 513\r\nPort Timothyville...   76     Male
# 14       822 Wilson Meadow\r\nMitchellmouth, RI 05935    0     Male
# 15            2573 Ryan Mission\r\nShortton, DC 01129   67     Male
# 16      481 Wilson Prairie\r\nKimberlymouth, LA 20064   46   Female
# 17          9909 John Creek\r\nEast Heather, NY 31266   44     Male
# 18   74669 Robles Drive\r\nPort Madisonbury, LA 63565   45     Male
# 19           7629 Ramos Knoll\r\nOwensmouth, NC 34420   54   Female
# 20      18356 Benjamin Roads\r\nSouth Nancy, NJ 58120   51     Male
# 21                           USNV Kim\r\nFPO AA 96043   39   Female
# 22          0873 Diaz Village\r\nSandrastad, DE 05796   53     Male
# 23   3678 Gloria Pine Apt. 652\r\nKevinfort, LA 80839   54     Male
# 24  8122 Jessica Knolls Apt. 880\r\nDakotafurt, WV...   47     Male
# 25       6146 Roman Shores\r\nNew Christine, OR 28920   55     Male
# 26            875 David Road\r\nPhillipfort, NC 26174   51     Male
# 27          781 Berry Spring\r\nTravismouth, NJ 11603   46   Female
# 28  7842 Curtis Vista Apt. 188\r\nLake Samuelburgh...   55     Male
# 29  9532 Jesse Roads Suite 253\r\nNorth Toni, NC 7...   52     Male
#
#    date_of_birth
# 0     1959-09-26
# 1     1966-10-28
# 2     1959-06-16
# 3     1980-09-09
# 4     1970-02-22
# 5     1973-09-25
# 6     1964-10-31
# 7     1952-07-23
# 8     1967-06-28
# 9     1988-11-07
# 10    1981-05-01
# 11    1957-08-10
# 12    1962-11-16
# 13    1943-04-21
# 14    1985-11-03
# 15    1952-08-06
# 16    1973-06-27
# 17    1975-01-10
# 18    1973-12-24
# 19    1965-05-06
# 20    1968-09-07
# 21    1980-06-11
# 22    1966-10-21
# 23    1965-04-25
# 24    1972-07-10
# 25    1963-12-19
# 26    1968-03-02
# 27    1972-12-11
# 28    1963-12-06
# 29    1967-09-04

# %%
# Approximate the date of the dataset by adding the age of people to their date_of_birth. Choose the highest value.
def add_age(row):
    return str(int(row["date_of_birth"][:4]) + row["age"]) + row["date_of_birth"][4:]

ds_date=[int(i) for i in data.apply(add_age, axis=1).max().split('-')]
print(ds_date)
# dataset_date.sort
# Out:
# [2019, 10, 25]

# %%
# Calculate the missing ages of people based on the dataset date
def fix_age(row):
    if row['age'] == 0:
        birth=[int(i) for i in row['date_of_birth'].split('-')]
        dif = [ds_date[0]-birth[0],ds_date[1]-birth[1],ds_date[2]-birth[2]]
        print(ds_date,'-',birth,'=',dif,end = ' --> age = ')
        if dif[2] < 0:
            dif[1] -= 1
        if dif[1] < 0:
            dif[0] -= 1
        print(dif[0])
        return dif[0]
    return row['age']
data['age'] = data.apply(fix_age, axis=1)
# Out:
# [2019, 10, 25] - [1985, 11, 3] = [34, -1, 22] --> age = 33
# [2019, 10, 25] - [1961, 4, 3] = [58, 6, 22] --> age = 58
# [2019, 10, 25] - [1980, 7, 30] = [39, 3, -5] --> age = 39
# [2019, 10, 25] - [1974, 11, 19] = [45, -1, 6] --> age = 44
# [2019, 10, 25] - [1970, 8, 18] = [49, 2, 7] --> age = 49
# [2019, 10, 25] - [1984, 9, 9] = [35, 1, 16] --> age = 35
# [2019, 10, 25] - [1937, 8, 18] = [82, 2, 7] --> age = 82
# [2019, 10, 25] - [1981, 10, 15] = [38, 0, 10] --> age = 38
# [2019, 10, 25] - [1972, 12, 18] = [47, -2, 7] --> age = 46
# [2019, 10, 25] - [1955, 11, 14] = [64, -1, 11] --> age = 63
# [2019, 10, 25] - [1953, 9, 30] = [66, 1, -5] --> age = 66
# [2019, 10, 25] - [1955, 8, 13] = [64, 2, 12] --> age = 64
# [2019, 10, 25] - [1961, 5, 29] = [58, 5, -4] --> age = 58
# [2019, 10, 25] - [1976, 7, 23] = [43, 3, 2] --> age = 43
# [2019, 10, 25] - [1963, 3, 24] = [56, 7, 1] --> age = 56
# [2019, 10, 25] - [1955, 5, 2] = [64, 5, 23] --> age = 64
# [2019, 10, 25] - [1967, 3, 7] = [52, 7, 18] --> age = 52
# [2019, 10, 25] - [1965, 11, 18] = [54, -1, 7] --> age = 53
# [2019, 10, 25] - [1951, 8, 19] = [68, 2, 6] --> age = 68
# [2019, 10, 25] - [1965, 11, 25] = [54, -1, 0] --> age = 53
# [2019, 10, 25] - [1955, 9, 30] = [64, 1, -5] --> age = 64
# [2019, 10, 25] - [1966, 11, 14] = [53, -1, 11] --> age = 52
# [2019, 10, 25] - [1970, 3, 9] = [49, 7, 16] --> age = 49
# [2019, 10, 25] - [1952, 12, 29] = [67, -2, -4] --> age = 66
# [2019, 10, 25] - [1977, 2, 23] = [42, 8, 2] --> age = 42
# [2019, 10, 25] - [1973, 10, 27] = [46, 0, -2] --> age = 45
# [2019, 10, 25] - [1970, 4, 16] = [49, 6, 9] --> age = 49
# [2019, 10, 25] - [1968, 11, 2] = [51, -1, 23] --> age = 50
# [2019, 10, 25] - [1961, 2, 4] = [58, 8, 21] --> age = 58
# [2019, 10, 25] - [1969, 1, 30] = [50, 9, -5] --> age = 50
# [2019, 10, 25] - [1985, 9, 7] = [34, 1, 18] --> age = 34
# [2019, 10, 25] - [1972, 3, 20] = [47, 7, 5] --> age = 47
# [2019, 10, 25] - [1978, 4, 21] = [41, 6, 4] --> age = 41
# [2019, 10, 25] - [1962, 2, 3] = [57, 8, 22] --> age = 57
# [2019, 10, 25] - [1950, 1, 30] = [69, 9, -5] --> age = 69
# [2019, 10, 25] - [1957, 10, 19] = [62, 0, 6] --> age = 62
# [2019, 10, 25] - [1960, 4, 30] = [59, 6, -5] --> age = 59
# %%
# Trim leading space from values
def trim_leading_space(row, d):
    for c in d.columns:
        if type(row[c])==str:
            row[c] = row[c].lstrip()
    return row

data2 = data2.apply(lambda row: trim_leading_space(row,data2), axis=1)
print_col_values(data2)
# Out:
# ••► race (6): ['White', 'Amer-Indian-Eskimo', 'Black', nan, 'Asian-Pac-Islander', 'Other']
#
# ••► marital-status (8): ['Married-civ-spouse', 'Divorced', 'Never-married', 'Widowed', 'Married-spouse-absent', 'Separated', nan, 'Married-AF-spouse']
#
# ••► occupation (16): ['Prof-specialty', 'Craft-repair', 'Tech-support', 'Transport-moving', 'Adm-clerical', 'Sales', 'Other-service', 'Exec-managerial', 'Machine-op-inspct', 'Protective-serv', 'Farming-fishing', 'Handlers-cleaners', '?', 'Priv-house-serv', nan, 'Armed-Forces']
#
# ••► pregnant (7): ['f', 't', 'F', 'FALSE', 'T', nan, 'TRUE']
#
# ••► education-num (17): [12.0, 9.0, 10.0, 13.0, 11.0, 6.0, 16.0, 3.0, 14.0, 8.0, 5.0, 7.0, 4.0, nan, 15.0, 2.0, 1.0]
#
# ••► relationship (7): ['Husband', 'Unmarried', 'Not-in-family', 'Own-child', 'Wife', 'Other-relative', nan]
#
# ••► education (17): ['Assoc-acdm', 'HS-grad', 'Some-college', 'Bachelors', 'Assoc-voc', '10th', 'Doctorate', '5th-6th', 'Masters', '12th', '9th', '11th', '7th-8th', nan, 'Prof-school', '1st-4th', 'Preschool']
#
# ••► class (3): [0.0, 1.0, nan]
#
# ••► income (3): ['>50K', '<=50K', nan]
#
# ••► native-country (40): ['Canada', 'United-States', 'Mexico', 'France', 'Nicaragua', nan, 'Cuba', 'Vietnam', '?', 'South', 'India', 'El-Salvador', 'Philippines', 'Guatemala', 'Portugal', 'Jamaica', 'England', 'Germany', 'Ecuador', 'Haiti', 'Japan', 'Puerto-Rico', 'Peru', 'Columbia', 'Iran', 'China', 'Greece', 'Thailand', 'Italy', 'Dominican-Republic', 'Laos', 'Taiwan', 'Ireland', 'Yugoslavia', 'Trinadad&Tobago', 'Cambodia', 'Poland', 'Honduras', 'Hong', 'Scotland']
#
# ••► workclass (9): ['Local-gov', 'Private', 'Self-emp-not-inc', 'Self-emp-inc', 'Federal-gov', 'State-gov', '?', 'Without-pay', nan]

# %%
# Merge duplicate rows by choosing the average of every available data, for non numeric data using the first available match
# If one of the numeric value is 0, while a none zero value exist, ignore the zero value
def is_nan(v):
    sv = str(v)
    return sv == '?' or sv == 'NaN' or sv == 'nan'

print('Detecting duplicates based on names...')
duplicate_names = list(data2[data2.duplicated(["name"])]["name"])
print('Found',len(duplicate_names),'duplicates, merging them...')
fixed_rows = []
for name in duplicate_names:
    rows = data2[data2['name'] == name]
    l = len(rows)
    print('\nMerging',l,'rows of name '+name+'...')
    bestRow = rows.iloc[0].copy()
    for c in data2.columns:
        if c == 'id': #Do not merge the id column
            continue
        print(c, list(rows[c]), end=' --> ')
        m = 1
        for i in range(1,l):
            row = rows.iloc[i]
            if is_nan(row[c]):
                continue
            if is_nan(bestRow[c]):
                bestRow[c] = row[c]
                m = 1
            elif (type(row[c])!=str) and row[c] != 0 and row[c] != 0.0:
                bestRow[c] += row[c]
                if bestRow[c] != row[c]:
                    m += 1
        if type(bestRow[c]) != str and m > 0:
            bestRow[c] /= m
        print([bestRow[c]],end='\n')
    fixed_rows.append(bestRow)

print('Applying changes...')
data2.drop_duplicates(subset=['name'],keep=False,inplace=True)
for r in fixed_rows:
    data2=data2.append(r)
# Out:
# Detecting duplicates based on names...
# Found 50 duplicates, merging them...
#
# Merging 2 rows of name Maurice Riley...
# name ['Maurice Riley', 'Maurice Riley'] --> ['Maurice Riley']
# address ['58487 Schneider Street\r\nGriffinfurt, RI 56689', '58487 Schneider Street\r\nGriffinfurt, RI 56689'] --> ['58487 Schneider Street\r\nGriffinfurt, RI 56689']
# race ['White', 'White'] --> ['White']
# marital-status ['Divorced', 'Divorced'] --> ['Divorced']
# occupation ['Machine-op-inspct', 'Machine-op-inspct'] --> ['Machine-op-inspct']
# pregnant ['f', 'f'] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Own-child', nan] --> ['Own-child']
# skewness_glucose [0.220758964, 0.220758964] --> [0.220758964]
# mean_glucose [121.0234375, 121.0234375] --> [121.0234375]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.311997839, 0.311997839] --> [0.311997839]
# education [nan, 'HS-grad'] --> ['HS-grad']
# fnlwgt [199816.0, 199816.0] --> [199816.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [-4594.807954, -4594.807954] --> [-4594.807954]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'2.526755853','std_oxygen':'14.28771907','kurtosis_oxygen':'8.427850384','skewness_oxygen':'100.9300203'}"] --> ["{'mean_oxygen':'2.526755853','std_oxygen':'14.28771907','kurtosis_oxygen':'8.427850384','skewness_oxygen':'100.9300203'}"]
# native-country [nan, 'United-States'] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, nan] --> [0.0]
# workclass [nan, 'Private'] --> ['Private']
# mean_oxygen [0.0, 2.526755853] --> [2.526755853]
# std_oxygen [0.0, 14.28771907] --> [14.28771907]
# kurtosis_oxygen [0.0, 8.427850384] --> [8.427850384]
# skewness_oxygen [0.0, 100.9300203] --> [100.9300203]
#
# Merging 2 rows of name Raymundo Marceau...
# name ['Raymundo Marceau', 'Raymundo Marceau'] --> ['Raymundo Marceau']
# address ['993 Heather View\r\nCarolynhaven, UT 99182', '993 Heather View\r\nCarolynhaven, UT 99182'] --> ['993 Heather View\r\nCarolynhaven, UT 99182']
# race [nan, 'White'] --> ['White']
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation [nan, 'Adm-clerical'] --> ['Adm-clerical']
# pregnant ['f', 'f'] --> ['f']
# education-num [nan, 9.0] --> [9.0]
# relationship ['Own-child', 'Own-child'] --> ['Own-child']
# skewness_glucose [0.9128628, 0.9128628] --> [0.9128628]
# mean_glucose [89.9609375, 89.9609375] --> [89.9609375]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.69710048, 0.69710048] --> [0.69710048]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [161063.0, 161063.0] --> [161063.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [45.06009916, 45.06009916] --> [45.06009916]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'2.034280936','std_oxygen':'15.26082034','kurtosis_oxygen':'9.965459227','skewness_oxygen':'116.5456637'}", "{'mean_oxygen':'2.034280936','std_oxygen':'15.26082034','kurtosis_oxygen':'9.965459227','skewness_oxygen':'116.5456637'}"] --> ["{'mean_oxygen':'2.034280936','std_oxygen':'15.26082034','kurtosis_oxygen':'9.965459227','skewness_oxygen':'116.5456637'}"]
# native-country [nan, 'United-States'] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [2.034280936, 2.034280936] --> [2.034280936]
# std_oxygen [15.26082034, 15.26082034] --> [15.26082034]
# kurtosis_oxygen [9.965459227, 9.965459227] --> [9.965459227]
# skewness_oxygen [116.5456637, 116.5456637] --> [116.5456637]
#
# Merging 2 rows of name Jackson Moorehouse...
# name ['Jackson Moorehouse', 'Jackson Moorehouse'] --> ['Jackson Moorehouse']
# address ['621 William Skyway\r\nPort Mark, LA 44554', '621 William Skyway\r\nPort Mark, LA 44554'] --> ['621 William Skyway\r\nPort Mark, LA 44554']
# race ['White', 'White'] --> ['White']
# marital-status [nan, 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Adm-clerical', 'Adm-clerical'] --> ['Adm-clerical']
# pregnant ['f', nan] --> ['f']
# education-num [13.0, nan] --> [13.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [0.251592504, 0.251592504] --> [0.251592504]
# mean_glucose [116.2890625, 116.2890625] --> [116.2890625]
# capital-gain [5178.0, 5178.0] --> [5178.0]
# kurtosis_glucose [0.293090485, 0.293090485] --> [0.293090485]
# education [nan, 'Bachelors'] --> ['Bachelors']
# fnlwgt [176814.0, 176814.0] --> [176814.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [5004.234962, 5004.234962] --> [5004.234962]
# income ['>50K', '>50K'] --> ['>50K']
# medical_info ["{'mean_oxygen':'2.581103679','std_oxygen':'16.575940900000006','kurtosis_oxygen':'8.850970509','skewness_oxygen':'92.53187169'}", "{'mean_oxygen':'2.581103679','std_oxygen':'16.575940900000006','kurtosis_oxygen':'8.850970509','skewness_oxygen':'92.53187169'}"] --> ["{'mean_oxygen':'2.581103679','std_oxygen':'16.575940900000006','kurtosis_oxygen':'8.850970509','skewness_oxygen':'92.53187169'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [40.0, nan] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [2.581103679, 2.581103679] --> [2.581103679]
# std_oxygen [16.575940900000006, 16.575940900000006] --> [16.575940900000006]
# kurtosis_oxygen [8.850970509, 8.850970509] --> [8.850970509]
# skewness_oxygen [92.53187169, 92.53187169] --> [92.53187169]
#
# Merging 2 rows of name Adam Perry...
# name ['Adam Perry', 'Adam Perry'] --> ['Adam Perry']
# address ['02726 Hale Lane\r\nLynchmouth, HI 33466', '02726 Hale Lane\r\nLynchmouth, HI 33466'] --> ['02726 Hale Lane\r\nLynchmouth, HI 33466']
# race ['White', 'White'] --> ['White']
# marital-status ['Widowed', 'Widowed'] --> ['Widowed']
# occupation ['Adm-clerical', 'Adm-clerical'] --> ['Adm-clerical']
# pregnant ['f', 'f'] --> ['f']
# education-num [10.0, 10.0] --> [10.0]
# relationship ['Unmarried', 'Unmarried'] --> ['Unmarried']
# skewness_glucose [18.53141618, nan] --> [18.53141618]
# mean_glucose [21.015625, 21.015625] --> [21.015625]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [4.452062155, nan] --> [4.452062155]
# education ['Some-college', 'Some-college'] --> ['Some-college']
# fnlwgt [156089.0, 156089.0] --> [156089.0]
# class [1.0, 1.0] --> [1.0]
# std_glucose [45.07406828, 45.07406828] --> [45.07406828]
# income ['<=50K', nan] --> ['<=50K']
# medical_info ["{'mean_oxygen':'121.30602009999998','std_oxygen':'67.25000775','kurtosis_oxygen':'-0.014069783999999998','skewness_oxygen':'-0.8117794429999999'}", nan] --> ["{'mean_oxygen':'121.30602009999998','std_oxygen':'67.25000775','kurtosis_oxygen':'-0.014069783999999998','skewness_oxygen':'-0.8117794429999999'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', nan] --> ['Private']
# mean_oxygen [121.30602009999998, 0.0] --> [121.30602009999998]
# std_oxygen [67.25000775, 0.0] --> [67.25000775]
# kurtosis_oxygen [-0.014069783999999998, 0.0] --> [-0.014069783999999998]
# skewness_oxygen [-0.8117794429999999, 0.0] --> [-0.8117794429999999]
#
# Merging 2 rows of name Michael Atchison...
# name ['Michael Atchison', 'Michael Atchison'] --> ['Michael Atchison']
# address ['4214 Kim Path\r\nLake Crystalstad, PA 11945', '4214 Kim Path\r\nLake Crystalstad, PA 11945'] --> ['4214 Kim Path\r\nLake Crystalstad, PA 11945']
# race [nan, 'White'] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Sales', 'Sales'] --> ['Sales']
# pregnant ['f', 'f'] --> ['f']
# education-num [13.0, nan] --> [13.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [0.765885591, 0.765885591] --> [0.765885591]
# mean_glucose [125.7578125, 125.7578125] --> [125.7578125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [nan, 0.062112591] --> [0.062112591]
# education ['Bachelors', 'Bachelors'] --> ['Bachelors']
# fnlwgt [198223.0, 198223.0] --> [198223.0]
# class [nan, 0.0] --> [0.0]
# std_glucose [43.97526757, 43.97526757] --> [43.97526757]
# income [nan, '>50K'] --> ['>50K']
# medical_info [nan, "{'mean_oxygen':'2.956521739','std_oxygen':'15.09462182','kurtosis_oxygen':'7.916994533','skewness_oxygen':'87.67514097'}"] --> ["{'mean_oxygen':'2.956521739','std_oxygen':'15.09462182','kurtosis_oxygen':'7.916994533','skewness_oxygen':'87.67514097'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [45.0, 45.0] --> [45.0]
# capital-loss [1902.0, 1902.0] --> [1902.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [0.0, 2.956521739] --> [2.956521739]
# std_oxygen [0.0, 15.09462182] --> [15.09462182]
# kurtosis_oxygen [0.0, 7.916994533] --> [7.916994533]
# skewness_oxygen [0.0, 87.67514097] --> [87.67514097]
#
# Merging 2 rows of name Thomas Porter...
# name ['Thomas Porter', 'Thomas Porter'] --> ['Thomas Porter']
# address ['930 Calvin Highway Suite 062\r\nEast Samuel, HI 21245', '930 Calvin Highway Suite 062\r\nEast Samuel, HI 21245'] --> ['930 Calvin Highway Suite 062\r\nEast Samuel, HI 21245']
# race ['White', nan] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Machine-op-inspct', 'Machine-op-inspct'] --> ['Machine-op-inspct']
# pregnant ['f', 'f'] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [-0.774892751, nan] --> [-0.774892751]
# mean_glucose [147.5, 147.5] --> [147.5]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [-0.30567424, -0.30567424] --> [-0.30567424]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [192588.0, 192588.0] --> [192588.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [61.31565359, 61.31565359] --> [61.31565359]
# income [nan, nan] --> [nan]
# medical_info ["{'mean_oxygen':'91.55183946','std_oxygen':'102.500925','kurtosis_oxygen':'0.330277214','skewness_oxygen':'-1.784581873'}", "{'mean_oxygen':'91.55183946','std_oxygen':'102.500925','kurtosis_oxygen':'0.330277214','skewness_oxygen':'-1.784581873'}"] --> ["{'mean_oxygen':'91.55183946','std_oxygen':'102.500925','kurtosis_oxygen':'0.330277214','skewness_oxygen':'-1.784581873'}"]
# native-country ['United-States', nan] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass [nan, 'Private'] --> ['Private']
# mean_oxygen [91.55183946, 91.55183946] --> [91.55183946]
# std_oxygen [102.500925, 102.500925] --> [102.500925]
# kurtosis_oxygen [0.330277214, 0.330277214] --> [0.330277214]
# skewness_oxygen [-1.784581873, -1.784581873] --> [-1.784581873]
#
# Merging 2 rows of name Michael Barnum...
# name ['Michael Barnum', 'Michael Barnum'] --> ['Michael Barnum']
# address ['9740 Joshua Roads\r\nVazquezmouth, TN 15386', '9740 Joshua Roads\r\nVazquezmouth, TN 15386'] --> ['9740 Joshua Roads\r\nVazquezmouth, TN 15386']
# race ['White', nan] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Exec-managerial', 'Exec-managerial'] --> ['Exec-managerial']
# pregnant ['f', 'f'] --> ['f']
# education-num [9.0, nan] --> [9.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [0.796409978, 0.796409978] --> [0.796409978]
# mean_glucose [136.875, 136.875] --> [136.875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [-0.044242101, -0.044242101] --> [-0.044242101]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [223327.0, 223327.0] --> [223327.0]
# class [0.0, nan] --> [0.0]
# std_glucose [40.81360067, 40.81360067] --> [40.81360067]
# income ['>50K', '>50K'] --> ['>50K']
# medical_info ["{'mean_oxygen':'1.180602007','std_oxygen':'13.925596300000002','kurtosis_oxygen':'13.89251477','skewness_oxygen':'209.9093542'}", nan] --> ["{'mean_oxygen':'1.180602007','std_oxygen':'13.925596300000002','kurtosis_oxygen':'13.89251477','skewness_oxygen':'209.9093542'}"]
# native-country ['United-States', nan] --> ['United-States']
# hours-per-week [40.0, nan] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [1.180602007, 0.0] --> [1.180602007]
# std_oxygen [13.925596300000002, 0.0] --> [13.925596300000002]
# kurtosis_oxygen [13.89251477, 0.0] --> [13.89251477]
# skewness_oxygen [209.9093542, 0.0] --> [209.9093542]
#
# Merging 2 rows of name Raul Vernon...
# name ['Raul Vernon', 'Raul Vernon'] --> ['Raul Vernon']
# address ['198 Wright Street Suite 397\r\nWendyshire, TN 04059', '198 Wright Street Suite 397\r\nWendyshire, TN 04059'] --> ['198 Wright Street Suite 397\r\nWendyshire, TN 04059']
# race [nan, 'Black'] --> ['Black']
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation ['Machine-op-inspct', nan] --> ['Machine-op-inspct']
# pregnant ['f', 'f'] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Not-in-family', 'Not-in-family'] --> ['Not-in-family']
# skewness_glucose [0.466079669, nan] --> [0.466079669]
# mean_glucose [89.6875, 89.6875] --> [89.6875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.437277565, 0.437277565] --> [0.437277565]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [221447.0, nan] --> [221447.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [43.50211022, nan] --> [43.50211022]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'5.973244147000001','std_oxygen':'31.32576626','kurtosis_oxygen':'5.831691247','skewness_oxygen':'34.73560627'}", "{'mean_oxygen':'5.973244147000001','std_oxygen':'31.32576626','kurtosis_oxygen':'5.831691247','skewness_oxygen':'34.73560627'}"] --> ["{'mean_oxygen':'5.973244147000001','std_oxygen':'31.32576626','kurtosis_oxygen':'5.831691247','skewness_oxygen':'34.73560627'}"]
# native-country ['United-States', nan] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [5.973244147000001, 5.973244147000001] --> [5.973244147000001]
# std_oxygen [31.32576626, 31.32576626] --> [31.32576626]
# kurtosis_oxygen [5.831691247, 5.831691247] --> [5.831691247]
# skewness_oxygen [34.73560627, 34.73560627] --> [34.73560627]
#
# Merging 2 rows of name William Valdez...
# name ['William Valdez', 'William Valdez'] --> ['William Valdez']
# address ['51548 John Branch\r\nEast Zacharyberg, AZ 21129', '51548 John Branch\r\nEast Zacharyberg, AZ 21129'] --> ['51548 John Branch\r\nEast Zacharyberg, AZ 21129']
# race ['White', 'White'] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Exec-managerial', 'Exec-managerial'] --> ['Exec-managerial']
# pregnant ['f', 'f'] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship [nan, 'Husband'] --> ['Husband']
# skewness_glucose [0.28442479800000003, 0.28442479800000003] --> [0.28442479800000003]
# mean_glucose [100.921875, nan] --> [100.921875]
# capital-gain [0.0, nan] --> [0.0]
# kurtosis_glucose [0.330426798, 0.330426798] --> [0.330426798]
# education [nan, 'HS-grad'] --> ['HS-grad']
# fnlwgt [165667.0, 165667.0] --> [165667.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [44.13165838, nan] --> [44.13165838]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'6.505016722000001','std_oxygen':'31.94852373','kurtosis_oxygen':'5.2170482730000005','skewness_oxygen':'27.27336922'}"] --> ["{'mean_oxygen':'6.505016722000001','std_oxygen':'31.94852373','kurtosis_oxygen':'5.2170482730000005','skewness_oxygen':'27.27336922'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Self-emp-inc', 'Self-emp-inc'] --> ['Self-emp-inc']
# mean_oxygen [0.0, 6.505016722000001] --> [6.505016722000001]
# std_oxygen [0.0, 31.94852373] --> [31.94852373]
# kurtosis_oxygen [0.0, 5.2170482730000005] --> [5.2170482730000005]
# skewness_oxygen [0.0, 27.27336922] --> [27.27336922]
#
# Merging 2 rows of name David Amaya...
# name ['David Amaya', 'David Amaya'] --> ['David Amaya']
# address ['4394 Rebecca Extension Suite 442\r\nNorth Jessicaborough, TX 66714', '4394 Rebecca Extension Suite 442\r\nNorth Jessicaborough, TX 66714'] --> ['4394 Rebecca Extension Suite 442\r\nNorth Jessicaborough, TX 66714']
# race ['White', 'White'] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Craft-repair', nan] --> ['Craft-repair']
# pregnant ['f', 'f'] --> ['f']
# education-num [nan, 9.0] --> [9.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [-0.7243369820000001, -0.7243369820000001] --> [-0.7243369820000001]
# mean_glucose [130.3828125, 130.3828125] --> [130.3828125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [nan, 0.099512815] --> [0.099512815]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [207668.0, 207668.0] --> [207668.0]
# class [nan, 0.0] --> [0.0]
# std_glucose [51.44522589, 51.44522589] --> [51.44522589]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'2.843645485','std_oxygen':'20.99095524','kurtosis_oxygen':'8.237226935','skewness_oxygen':'72.26463286'}"] --> ["{'mean_oxygen':'2.843645485','std_oxygen':'20.99095524','kurtosis_oxygen':'8.237226935','skewness_oxygen':'72.26463286'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [50.0, 50.0] --> [50.0]
# capital-loss [nan, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [0.0, 2.843645485] --> [2.843645485]
# std_oxygen [0.0, 20.99095524] --> [20.99095524]
# kurtosis_oxygen [0.0, 8.237226935] --> [8.237226935]
# skewness_oxygen [0.0, 72.26463286] --> [72.26463286]
#
# Merging 2 rows of name Anthony Sauer...
# name ['Anthony Sauer', 'Anthony Sauer'] --> ['Anthony Sauer']
# address ['29005 Gonzalez Drive\r\nJuanbury, MN 72336', '29005 Gonzalez Drive\r\nJuanbury, MN 72336'] --> ['29005 Gonzalez Drive\r\nJuanbury, MN 72336']
# race ['White', 'White'] --> ['White']
# marital-status [nan, 'Never-married'] --> ['Never-married']
# occupation ['Farming-fishing', 'Farming-fishing'] --> ['Farming-fishing']
# pregnant ['f', 'f'] --> ['f']
# education-num [10.0, 10.0] --> [10.0]
# relationship ['Own-child', 'Own-child'] --> ['Own-child']
# skewness_glucose [12.39396866, 12.39396866] --> [12.39396866]
# mean_glucose [66.78125, 66.78125] --> [66.78125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [2.623626489, 2.623626489] --> [2.623626489]
# education [nan, 'Some-college'] --> ['Some-college']
# fnlwgt [25631.0, 25631.0] --> [25631.0]
# class [1.0, nan] --> [1.0]
# std_glucose [nan, nan] --> [nan]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'14.80852843','std_oxygen':'46.38263458','kurtosis_oxygen':'3.617249692','skewness_oxygen':'12.61488438'}", nan] --> ["{'mean_oxygen':'14.80852843','std_oxygen':'46.38263458','kurtosis_oxygen':'3.617249692','skewness_oxygen':'12.61488438'}"]
# native-country ['United-States', nan] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Self-emp-not-inc', nan] --> ['Self-emp-not-inc']
# mean_oxygen [14.80852843, 0.0] --> [14.80852843]
# std_oxygen [46.38263458, 0.0] --> [46.38263458]
# kurtosis_oxygen [3.617249692, 0.0] --> [3.617249692]
# skewness_oxygen [12.61488438, 0.0] --> [12.61488438]
#
# Merging 2 rows of name Richard Stokes...
# name ['Richard Stokes', 'Richard Stokes'] --> ['Richard Stokes']
# address ['PSC 6026, Box 2244\r\nAPO AA 76838', 'PSC 6026, Box 2244\r\nAPO AA 76838'] --> ['PSC 6026, Box 2244\r\nAPO AA 76838']
# race [nan, 'Black'] --> ['Black']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Protective-serv', 'Protective-serv'] --> ['Protective-serv']
# pregnant ['f', 'f'] --> ['f']
# education-num [nan, 13.0] --> [13.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [nan, -0.359567906] --> [-0.359567906]
# mean_glucose [124.2421875, 124.2421875] --> [124.2421875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.115073981, 0.115073981] --> [0.115073981]
# education ['Bachelors', 'Bachelors'] --> ['Bachelors']
# fnlwgt [247205.0, 247205.0] --> [247205.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [51.61133991, 51.61133991] --> [51.61133991]
# income [nan, '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'4.122909699','std_oxygen':'23.74433452','kurtosis_oxygen':'6.826181114','skewness_oxygen':'51.37034912'}"] --> ["{'mean_oxygen':'4.122909699','std_oxygen':'23.74433452','kurtosis_oxygen':'6.826181114','skewness_oxygen':'51.37034912'}"]
# native-country ['England', 'England'] --> ['England']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [0.0, 4.122909699] --> [4.122909699]
# std_oxygen [0.0, 23.74433452] --> [23.74433452]
# kurtosis_oxygen [0.0, 6.826181114] --> [6.826181114]
# skewness_oxygen [0.0, 51.37034912] --> [51.37034912]
#
# Merging 2 rows of name Mike Rm...
# name ['Mike Rm', 'Mike Rm'] --> ['Mike Rm']
# address ['8317 Sarah Streets Apt. 987\r\nWrighttown, NY 94031', '8317 Sarah Streets Apt. 987\r\nWrighttown, NY 94031'] --> ['8317 Sarah Streets Apt. 987\r\nWrighttown, NY 94031']
# race ['Other', nan] --> ['Other']
# marital-status ['Divorced', 'Divorced'] --> ['Divorced']
# occupation ['Craft-repair', 'Craft-repair'] --> ['Craft-repair']
# pregnant ['f', nan] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Not-in-family', nan] --> ['Not-in-family']
# skewness_glucose [0.45914166, nan] --> [0.45914166]
# mean_glucose [137.0078125, 137.0078125] --> [137.0078125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [-0.1151464, -0.1151464] --> [-0.1151464]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [228723.0, 228723.0] --> [228723.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [41.42585547, 41.42585547] --> [41.42585547]
# income ['>50K', '>50K'] --> ['>50K']
# medical_info ["{'mean_oxygen':'1.429765886','std_oxygen':'11.30110467','kurtosis_oxygen':'13.02145739','skewness_oxygen':'234.077558'}", "{'mean_oxygen':'1.429765886','std_oxygen':'11.30110467','kurtosis_oxygen':'13.02145739','skewness_oxygen':'234.077558'}"] --> ["{'mean_oxygen':'1.429765886','std_oxygen':'11.30110467','kurtosis_oxygen':'13.02145739','skewness_oxygen':'234.077558'}"]
# native-country ['?', nan] --> ['?']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Local-gov', nan] --> ['Local-gov']
# mean_oxygen [1.429765886, 1.429765886] --> [1.429765886]
# std_oxygen [11.30110467, 11.30110467] --> [11.30110467]
# kurtosis_oxygen [13.02145739, 13.02145739] --> [13.02145739]
# skewness_oxygen [234.077558, 234.077558] --> [234.077558]
# Merging 2 rows of name Roy Wiederwax...
# name ['Roy Wiederwax', 'Roy Wiederwax'] --> ['Roy Wiederwax']
# address ['36618 Dawn Forks\r\nJosephmouth, ME 24976', '36618 Dawn Forks\r\nJosephmouth, ME 24976'] --> ['36618 Dawn Forks\r\nJosephmouth, ME 24976']
# race ['White', 'White'] --> ['White']
# marital-status ['Divorced', 'Divorced'] --> ['Divorced']
# occupation ['Prof-specialty', 'Prof-specialty'] --> ['Prof-specialty']
# pregnant ['f', 'f'] --> ['f']
# education-num [15.0, 15.0] --> [15.0]
# relationship ['Not-in-family', 'Not-in-family'] --> ['Not-in-family']
# skewness_glucose [0.013982403, 0.013982403] --> [0.013982403]
# mean_glucose [113.0, 113.0] --> [113.0]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.25406438, nan] --> [0.25406438]
# education ['Prof-school', 'Prof-school'] --> ['Prof-school']
# fnlwgt [66504.0, nan] --> [66504.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [52.7206672, 52.7206672] --> [52.7206672]
# income ['>50K', nan] --> ['>50K']
# medical_info ["{'mean_oxygen':'2.987458194','std_oxygen':'18.92934433','kurtosis_oxygen':'8.020098696','skewness_oxygen':'73.22285347'}", "{'mean_oxygen':'2.987458194','std_oxygen':'18.92934433','kurtosis_oxygen':'8.020098696','skewness_oxygen':'73.22285347'}"] --> ["{'mean_oxygen':'2.987458194','std_oxygen':'18.92934433','kurtosis_oxygen':'8.020098696','skewness_oxygen':'73.22285347'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [50.0, nan] --> [50.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Federal-gov', nan] --> ['Federal-gov']
# mean_oxygen [2.987458194, 2.987458194] --> [2.987458194]
# std_oxygen [18.92934433, 18.92934433] --> [18.92934433]
# kurtosis_oxygen [8.020098696, 8.020098696] --> [8.020098696]
# skewness_oxygen [73.22285347, 73.22285347] --> [73.22285347]
#
# Merging 2 rows of name John Cuff...
# name ['John Cuff', 'John Cuff'] --> ['John Cuff']
# address ['87184 Jesus Pines Apt. 478\r\nEdwardtown, AK 57408', '87184 Jesus Pines Apt. 478\r\nEdwardtown, AK 57408'] --> ['87184 Jesus Pines Apt. 478\r\nEdwardtown, AK 57408']
# race [nan, 'White'] --> ['White']
# marital-status [nan, 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Other-service', 'Other-service'] --> ['Other-service']
# pregnant ['f', 'f'] --> ['f']
# education-num [nan, 7.0] --> [7.0]
# relationship ['Wife', 'Wife'] --> ['Wife']
# skewness_glucose [0.182466129, 0.182466129] --> [0.182466129]
# mean_glucose [98.359375, 98.359375] --> [98.359375]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.5677573370000001, 0.5677573370000001] --> [0.5677573370000001]
# education ['11th', '11th'] --> ['11th']
# fnlwgt [194962.0, 194962.0] --> [194962.0]
# class [nan, 0.0] --> [0.0]
# std_glucose [46.30178425, 46.30178425] --> [46.30178425]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'0.837792642','std_oxygen':'12.74730386','kurtosis_oxygen':'16.94832782','skewness_oxygen':'305.536961'}", "{'mean_oxygen':'0.837792642','std_oxygen':'12.74730386','kurtosis_oxygen':'16.94832782','skewness_oxygen':'305.536961'}"] --> ["{'mean_oxygen':'0.837792642','std_oxygen':'12.74730386','kurtosis_oxygen':'16.94832782','skewness_oxygen':'305.536961'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [nan, 6.0] --> [6.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [0.837792642, 0.837792642] --> [0.837792642]
# std_oxygen [12.74730386, 12.74730386] --> [12.74730386]
# kurtosis_oxygen [16.94832782, 16.94832782] --> [16.94832782]
# skewness_oxygen [305.536961, 305.536961] --> [305.536961]
#
# Merging 2 rows of name Jay Wells...
# name ['Jay Wells', 'Jay Wells'] --> ['Jay Wells']
# address ['063 Day Flats\r\nJudymouth, FL 61565', '063 Day Flats\r\nJudymouth, FL 61565'] --> ['063 Day Flats\r\nJudymouth, FL 61565']
# race ['Black', 'Black'] --> ['Black']
# marital-status [nan, 'Divorced'] --> ['Divorced']
# occupation ['Other-service', 'Other-service'] --> ['Other-service']
# pregnant [nan, nan] --> [nan]
# education-num [11.0, 11.0] --> [11.0]
# relationship ['Unmarried', nan] --> ['Unmarried']
# skewness_glucose [0.060911664, 0.060911664] --> [0.060911664]
# mean_glucose [106.71875, 106.71875] --> [106.71875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.48313819, 0.48313819] --> [0.48313819]
# education ['Assoc-voc', 'Assoc-voc'] --> ['Assoc-voc']
# fnlwgt [211751.0, 211751.0] --> [211751.0]
# class [1.0, 1.0] --> [1.0]
# std_glucose [48.59991922, 48.59991922] --> [48.59991922]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'6.269230769','std_oxygen':'29.92992523','kurtosis_oxygen':'6.026227617999999','skewness_oxygen':'38.46886389'}"] --> ["{'mean_oxygen':'6.269230769','std_oxygen':'29.92992523','kurtosis_oxygen':'6.026227617999999','skewness_oxygen':'38.46886389'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [nan, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [0.0, 6.269230769] --> [6.269230769]
# std_oxygen [0.0, 29.92992523] --> [29.92992523]
# kurtosis_oxygen [0.0, 6.026227617999999] --> [6.026227617999999]
# skewness_oxygen [0.0, 38.46886389] --> [38.46886389]
#
# Merging 2 rows of name Frank Holland...
# name ['Frank Holland', 'Frank Holland'] --> ['Frank Holland']
# address ['0382 Smith Groves\r\nBriannafurt, OH 35432', '0382 Smith Groves\r\nBriannafurt, OH 35432'] --> ['0382 Smith Groves\r\nBriannafurt, OH 35432']
# race ['White', 'White'] --> ['White']
# marital-status ['Divorced', 'Divorced'] --> ['Divorced']
# occupation ['Other-service', nan] --> ['Other-service']
# pregnant [nan, 'FALSE'] --> ['FALSE']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Unmarried', 'Unmarried'] --> ['Unmarried']
# skewness_glucose [0.899046895, 0.899046895] --> [0.899046895]
# mean_glucose [95.5546875, 95.5546875] --> [95.5546875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.547778175, 0.547778175] --> [0.547778175]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [30063.0, 30063.0] --> [30063.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [43.76996127, 43.76996127] --> [43.76996127]
# income [nan, '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'2.315217391','std_oxygen':'14.36097471','kurtosis_oxygen':'9.431659666','skewness_oxygen':'116.9497257'}", "{'mean_oxygen':'2.315217391','std_oxygen':'14.36097471','kurtosis_oxygen':'9.431659666','skewness_oxygen':'116.9497257'}"] --> ["{'mean_oxygen':'2.315217391','std_oxygen':'14.36097471','kurtosis_oxygen':'9.431659666','skewness_oxygen':'116.9497257'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [32.0, 32.0] --> [32.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [2.315217391, 2.315217391] --> [2.315217391]
# std_oxygen [14.36097471, 14.36097471] --> [14.36097471]
# kurtosis_oxygen [9.431659666, 9.431659666] --> [9.431659666]
# skewness_oxygen [116.9497257, 116.9497257] --> [116.9497257]
#
# Merging 2 rows of name Clark Smith...
# name ['Clark Smith', 'Clark Smith'] --> ['Clark Smith']
# address ['9472 Megan Forge\r\nNorth Selenaborough, NV 88450', '9472 Megan Forge\r\nNorth Selenaborough, NV 88450'] --> ['9472 Megan Forge\r\nNorth Selenaborough, NV 88450']
# race ['White', nan] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['?', '?'] --> ['?']
# pregnant ['f', 'f'] --> ['f']
# education-num [13.0, 13.0] --> [13.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [5.185332343, 5.185332343] --> [5.185332343]
# mean_glucose [90.3671875, nan] --> [90.3671875]
# capital-gain [9386.0, 9386.0] --> [9386.0]
# kurtosis_glucose [1.553546259, 1.553546259] --> [1.553546259]
# education ['Bachelors', nan] --> ['Bachelors']
# fnlwgt [35303.0, 35303.0] --> [35303.0]
# class [1.0, 1.0] --> [1.0]
# std_glucose [36.78566957, nan] --> [36.78566957]
# income ['>50K', '>50K'] --> ['>50K']
# medical_info ["{'mean_oxygen':'5.619565217000001','std_oxygen':'30.87884814','kurtosis_oxygen':'5.991010293','skewness_oxygen':'36.56053633'}", "{'mean_oxygen':'5.619565217000001','std_oxygen':'30.87884814','kurtosis_oxygen':'5.991010293','skewness_oxygen':'36.56053633'}"] --> ["{'mean_oxygen':'5.619565217000001','std_oxygen':'30.87884814','kurtosis_oxygen':'5.991010293','skewness_oxygen':'36.56053633'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [30.0, 30.0] --> [30.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['?', nan] --> ['?']
# mean_oxygen [5.619565217000001, 5.619565217000001] --> [5.619565217000001]
# std_oxygen [30.87884814, 30.87884814] --> [30.87884814]
# kurtosis_oxygen [5.991010293, 5.991010293] --> [5.991010293]
# skewness_oxygen [36.56053633, 36.56053633] --> [36.56053633]
#
# Merging 2 rows of name James Limerick...
# name ['James Limerick', 'James Limerick'] --> ['James Limerick']
# address ['78039 Velez Streets\r\nNew Wendytown, CO 99241', '78039 Velez Streets\r\nNew Wendytown, CO 99241'] --> ['78039 Velez Streets\r\nNew Wendytown, CO 99241']
# race ['Black', 'Black'] --> ['Black']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation [nan, 'Craft-repair'] --> ['Craft-repair']
# pregnant ['f', 'f'] --> ['f']
# education-num [10.0, 10.0] --> [10.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [0.210647601, 0.210647601] --> [0.210647601]
# mean_glucose [126.8828125, 126.8828125] --> [126.8828125]
# capital-gain [0.0, nan] --> [0.0]
# kurtosis_glucose [0.046673846, nan] --> [0.046673846]
# education ['Some-college', 'Some-college'] --> ['Some-college']
# fnlwgt [178383.0, 178383.0] --> [178383.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [48.68402926, 48.68402926] --> [48.68402926]
# income ['<=50K', nan] --> ['<=50K']
# medical_info ["{'mean_oxygen':'0.865384615','std_oxygen':'9.3767006','kurtosis_oxygen':'19.21055381','skewness_oxygen':'467.6307624'}", nan] --> ["{'mean_oxygen':'0.865384615','std_oxygen':'9.3767006','kurtosis_oxygen':'19.21055381','skewness_oxygen':'467.6307624'}"]
# native-country ['United-States', nan] --> ['United-States']
# hours-per-week [70.0, 70.0] --> [70.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Self-emp-inc', 'Self-emp-inc'] --> ['Self-emp-inc']
# mean_oxygen [0.865384615, 0.0] --> [0.865384615]
# std_oxygen [9.3767006, 0.0] --> [9.3767006]
# kurtosis_oxygen [19.21055381, 0.0] --> [19.21055381]
# skewness_oxygen [467.6307624, 0.0] --> [467.6307624]
#
# Merging 2 rows of name Vincent Farmer...
# name ['Vincent Farmer', 'Vincent Farmer'] --> ['Vincent Farmer']
# address ['8178 Bell Passage\r\nNorth William, NE 41912', '8178 Bell Passage\r\nNorth William, NE 41912'] --> ['8178 Bell Passage\r\nNorth William, NE 41912']
# race ['White', 'White'] --> ['White']
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation ['Prof-specialty', 'Prof-specialty'] --> ['Prof-specialty']
# pregnant ['f', 'f'] --> ['f']
# education-num [16.0, 16.0] --> [16.0]
# relationship ['Not-in-family', 'Not-in-family'] --> ['Not-in-family']
# skewness_glucose [nan, 0.5987826310000001] --> [0.5987826310000001]
# mean_glucose [nan, 97.84375] --> [97.84375]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.499224287, 0.499224287] --> [0.499224287]
# education ['Doctorate', 'Doctorate'] --> ['Doctorate']
# fnlwgt [nan, 186385.0] --> [186385.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [nan, nan] --> [nan]
# income [nan, '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'1.97993311','std_oxygen':'13.17953968','kurtosis_oxygen':'10.7578308','skewness_oxygen':'152.31530580000003'}", "{'mean_oxygen':'1.97993311','std_oxygen':'13.17953968','kurtosis_oxygen':'10.7578308','skewness_oxygen':'152.31530580000003'}"] --> ["{'mean_oxygen':'1.97993311','std_oxygen':'13.17953968','kurtosis_oxygen':'10.7578308','skewness_oxygen':'152.31530580000003'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [8.0, 8.0] --> [8.0]
# capital-loss [nan, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [1.97993311, 1.97993311] --> [1.97993311]
# std_oxygen [13.17953968, 13.17953968] --> [13.17953968]
# kurtosis_oxygen [10.7578308, 10.7578308] --> [10.7578308]
# skewness_oxygen [152.31530580000003, 152.31530580000003] --> [152.31530580000003]
#
# Merging 2 rows of name Richard Keith...
# name ['Richard Keith', 'Richard Keith'] --> ['Richard Keith']
# address ['42463 Christina Run\r\nDanielmouth, WY 92187', '42463 Christina Run\r\nDanielmouth, WY 92187'] --> ['42463 Christina Run\r\nDanielmouth, WY 92187']
# race [nan, 'White'] --> ['White']
# marital-status ['Divorced', 'Divorced'] --> ['Divorced']
# occupation ['Exec-managerial', 'Exec-managerial'] --> ['Exec-managerial']
# pregnant ['f', 'f'] --> ['f']
# education-num [11.0, 11.0] --> [11.0]
# relationship ['Own-child', 'Own-child'] --> ['Own-child']
# skewness_glucose [nan, -0.26160258] --> [-0.26160258]
# mean_glucose [158.4296875, 158.4296875] --> [158.4296875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [-0.283403937, -0.283403937] --> [-0.283403937]
# education ['Assoc-voc', 'Assoc-voc'] --> ['Assoc-voc']
# fnlwgt [282753.0, 282753.0] --> [282753.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [50.08019874, 50.08019874] --> [50.08019874]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'4.919732441','std_oxygen':'27.85473988','kurtosis_oxygen':'5.9424108470000006','skewness_oxygen':'35.41269686'}", nan] --> ["{'mean_oxygen':'4.919732441','std_oxygen':'27.85473988','kurtosis_oxygen':'5.9424108470000006','skewness_oxygen':'35.41269686'}"]
# native-country [nan, 'United-States'] --> ['United-States']
# hours-per-week [nan, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Local-gov', 'Local-gov'] --> ['Local-gov']
# mean_oxygen [4.919732441, 0.0] --> [4.919732441]
# std_oxygen [27.85473988, 0.0] --> [27.85473988]
# kurtosis_oxygen [5.9424108470000006, 0.0] --> [5.9424108470000006]
# skewness_oxygen [35.41269686, 0.0] --> [35.41269686]
#
# Merging 2 rows of name Darrell Dickey...
# name ['Darrell Dickey', 'Darrell Dickey'] --> ['Darrell Dickey']
# address ['8459 Johnny Port\r\nEast Angelica, NV 04193', '8459 Johnny Port\r\nEast Angelica, NV 04193'] --> ['8459 Johnny Port\r\nEast Angelica, NV 04193']
# race ['White', 'White'] --> ['White']
# marital-status [nan, 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Adm-clerical', 'Adm-clerical'] --> ['Adm-clerical']
# pregnant ['f', 'f'] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Wife', 'Wife'] --> ['Wife']
# skewness_glucose [-0.365369513, -0.365369513] --> [-0.365369513]
# mean_glucose [nan, nan] --> [nan]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.002098728, 0.002098728] --> [0.002098728]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [175821.0, 175821.0] --> [175821.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [5143.1044550000015, 5143.1044550000015] --> [5143.1044550000015]
# income [nan, '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'4.759197324','std_oxygen':'23.95851782','kurtosis_oxygen':'6.209460367999999','skewness_oxygen':'43.0902091'}", "{'mean_oxygen':'4.759197324','std_oxygen':'23.95851782','kurtosis_oxygen':'6.209460367999999','skewness_oxygen':'43.0902091'}"] --> ["{'mean_oxygen':'4.759197324','std_oxygen':'23.95851782','kurtosis_oxygen':'6.209460367999999','skewness_oxygen':'43.0902091'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [nan, 34.0] --> [34.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [4.759197324, 4.759197324] --> [4.759197324]
# std_oxygen [23.95851782, 23.95851782] --> [23.95851782]
# kurtosis_oxygen [6.209460367999999, 6.209460367999999] --> [6.209460367999999]
# skewness_oxygen [43.0902091, 43.0902091] --> [43.0902091]
#
# Merging 2 rows of name Willie Gerace...
# name ['Willie Gerace', 'Willie Gerace'] --> ['Willie Gerace']
# address ['Unit 0472 Box 3935\r\nDPO AA 56086', 'Unit 0472 Box 3935\r\nDPO AA 56086'] --> ['Unit 0472 Box 3935\r\nDPO AA 56086']
# race ['White', 'White'] --> ['White']
# marital-status ['Divorced', 'Divorced'] --> ['Divorced']
# occupation [nan, 'Farming-fishing'] --> ['Farming-fishing']
# pregnant ['f', 'f'] --> ['f']
# education-num [9.0, nan] --> [9.0]
# relationship ['Unmarried', 'Unmarried'] --> ['Unmarried']
# skewness_glucose [0.120914904, 0.120914904] --> [0.120914904]
# mean_glucose [129.296875, 129.296875] --> [129.296875]
# capital-gain [0.0, nan] --> [0.0]
# kurtosis_glucose [-0.036039663, -0.036039663] --> [-0.036039663]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [33001.0, 33001.0] --> [33001.0]
# class [0.0, nan] --> [0.0]
# std_glucose [47.47093838, 47.47093838] --> [47.47093838]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'2.046822742','std_oxygen':'12.98891275','kurtosis_oxygen':'10.21195546','skewness_oxygen':'145.74362680000004'}", "{'mean_oxygen':'2.046822742','std_oxygen':'12.98891275','kurtosis_oxygen':'10.21195546','skewness_oxygen':'145.74362680000004'}"] --> ["{'mean_oxygen':'2.046822742','std_oxygen':'12.98891275','kurtosis_oxygen':'10.21195546','skewness_oxygen':'145.74362680000004'}"]
# native-country [nan, 'United-States'] --> ['United-States']
# hours-per-week [50.0, nan] --> [50.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [2.046822742, 2.046822742] --> [2.046822742]
# std_oxygen [12.98891275, 12.98891275] --> [12.98891275]
# kurtosis_oxygen [10.21195546, 10.21195546] --> [10.21195546]
# skewness_oxygen [145.74362680000004, 145.74362680000004] --> [145.74362680000004]
#
# Merging 2 rows of name Napoleon Branner...
# name ['Napoleon Branner', 'Napoleon Branner'] --> ['Napoleon Branner']
# address ['0837 Adams Prairie Suite 170\r\nNorth Jessicabury, CT 17631', '0837 Adams Prairie Suite 170\r\nNorth Jessicabury, CT 17631'] --> ['0837 Adams Prairie Suite 170\r\nNorth Jessicabury, CT 17631']
# race ['White', 'White'] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation [nan, 'Transport-moving'] --> ['Transport-moving']
# pregnant ['f', 'f'] --> ['f']
# education-num [10.0, 10.0] --> [10.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [5.474289821, 5.474289821] --> [5.474289821]
# mean_glucose [nan, 75.53125] --> [75.53125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [1.80386797, 1.80386797] --> [1.80386797]
# education ['Some-college', nan] --> ['Some-college']
# fnlwgt [nan, 210525.0] --> [210525.0]
# class [1.0, 1.0] --> [1.0]
# std_glucose [38.67067233, 38.67067233] --> [38.67067233]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'21.51839465','std_oxygen':'54.84521085','kurtosis_oxygen':'2.694580166','skewness_oxygen':'6.3625074'}"] --> ["{'mean_oxygen':'21.51839465','std_oxygen':'54.84521085','kurtosis_oxygen':'2.694580166','skewness_oxygen':'6.3625074'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [nan, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [0.0, 21.51839465] --> [21.51839465]
# std_oxygen [0.0, 54.84521085] --> [54.84521085]
# kurtosis_oxygen [0.0, 2.694580166] --> [2.694580166]
# skewness_oxygen [0.0, 6.3625074] --> [6.3625074]
#
# Merging 2 rows of name Wallace Street...
# name ['Wallace Street', 'Wallace Street'] --> ['Wallace Street']
# address ['9909 John Creek\r\nEast Heather, NY 31266', '9909 John Creek\r\nEast Heather, NY 31266'] --> ['9909 John Creek\r\nEast Heather, NY 31266']
# race ['Black', nan] --> ['Black']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Handlers-cleaners', 'Handlers-cleaners'] --> ['Handlers-cleaners']
# pregnant ['f', 'f'] --> ['f']
# education-num [10.0, 10.0] --> [10.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [-0.25225520100000004, -0.25225520100000004] --> [-0.25225520100000004]
# mean_glucose [140.515625, 140.515625] --> [140.515625]
# capital-gain [nan, 7298.0] --> [7298.0]
# kurtosis_glucose [0.032943787, 0.032943787] --> [0.032943787]
# education ['Some-college', nan] --> ['Some-college']
# fnlwgt [189824.0, 189824.0] --> [189824.0]
# class [nan, nan] --> [nan]
# std_glucose [47.35536935, 47.35536935] --> [47.35536935]
# income ['>50K', '>50K'] --> ['>50K']
# medical_info ["{'mean_oxygen':'3.772575251','std_oxygen':'19.14934573','kurtosis_oxygen':'6.289634408','skewness_oxygen':'47.73565619'}", "{'mean_oxygen':'3.772575251','std_oxygen':'19.14934573','kurtosis_oxygen':'6.289634408','skewness_oxygen':'47.73565619'}"] --> ["{'mean_oxygen':'3.772575251','std_oxygen':'19.14934573','kurtosis_oxygen':'6.289634408','skewness_oxygen':'47.73565619'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Local-gov', 'Local-gov'] --> ['Local-gov']
# mean_oxygen [3.772575251, 3.772575251] --> [3.772575251]
# std_oxygen [19.14934573, 19.14934573] --> [19.14934573]
# kurtosis_oxygen [6.289634408, 6.289634408] --> [6.289634408]
# skewness_oxygen [47.73565619, 47.73565619] --> [47.73565619]
#
# Merging 2 rows of name Luis Coulter...
# name ['Luis Coulter', 'Luis Coulter'] --> ['Luis Coulter']
# address ['238 Mark Vista Apt. 619\r\nPeckborough, MA 30987', '238 Mark Vista Apt. 619\r\nPeckborough, MA 30987'] --> ['238 Mark Vista Apt. 619\r\nPeckborough, MA 30987']
# race ['White', 'White'] --> ['White']
# marital-status ['Widowed', 'Widowed'] --> ['Widowed']
# occupation ['Exec-managerial', 'Exec-managerial'] --> ['Exec-managerial']
# pregnant ['f', nan] --> ['f']
# education-num [13.0, nan] --> [13.0]
# relationship [nan, 'Not-in-family'] --> ['Not-in-family']
# skewness_glucose [0.93674104, 0.93674104] --> [0.93674104]
# mean_glucose [129.671875, 129.671875] --> [129.671875]
# capital-gain [10520.0, 10520.0] --> [10520.0]
# kurtosis_glucose [0.330588431, 0.330588431] --> [0.330588431]
# education ['Bachelors', 'Bachelors'] --> ['Bachelors']
# fnlwgt [103344.0, nan] --> [103344.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [42.73137558, nan] --> [42.73137558]
# income ['>50K', nan] --> ['>50K']
# medical_info ["{'mean_oxygen':'1.876254181','std_oxygen':'11.88946041','kurtosis_oxygen':'11.82308563','skewness_oxygen':'199.969665'}", "{'mean_oxygen':'1.876254181','std_oxygen':'11.88946041','kurtosis_oxygen':'11.82308563','skewness_oxygen':'199.969665'}"] --> ["{'mean_oxygen':'1.876254181','std_oxygen':'11.88946041','kurtosis_oxygen':'11.82308563','skewness_oxygen':'199.969665'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [50.0, 50.0] --> [50.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [1.876254181, 1.876254181] --> [1.876254181]
# std_oxygen [11.88946041, 11.88946041] --> [11.88946041]
# kurtosis_oxygen [11.82308563, 11.82308563] --> [11.82308563]
# skewness_oxygen [199.969665, 199.969665] --> [199.969665]
#
# Merging 2 rows of name Wesley Srey...
# name ['Wesley Srey', 'Wesley Srey'] --> ['Wesley Srey']
# address ['2824 Lisa Keys Apt. 217\r\nWest Savannah, AZ 38232', '2824 Lisa Keys Apt. 217\r\nWest Savannah, AZ 38232'] --> ['2824 Lisa Keys Apt. 217\r\nWest Savannah, AZ 38232']
# race ['White', 'White'] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Handlers-cleaners', 'Handlers-cleaners'] --> ['Handlers-cleaners']
# pregnant [nan, 'f'] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Husband', nan] --> ['Husband']
# skewness_glucose [-0.5641410570000001, -0.5641410570000001] --> [-0.5641410570000001]
# mean_glucose [120.9140625, 120.9140625] --> [120.9140625]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [-0.039545841, -0.039545841] --> [-0.039545841]
# education ['HS-grad', 'HS-grad'] --> ['HS-grad']
# fnlwgt [208249.0, 208249.0] --> [208249.0]
# class [nan, 0.0] --> [0.0]
# std_glucose [54.85022609, 54.85022609] --> [54.85022609]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'11.44230769','std_oxygen':'43.47573632','kurtosis_oxygen':'3.76497994','skewness_oxygen':'12.96997299'}", "{'mean_oxygen':'11.44230769','std_oxygen':'43.47573632','kurtosis_oxygen':'3.76497994','skewness_oxygen':'12.96997299'}"] --> ["{'mean_oxygen':'11.44230769','std_oxygen':'43.47573632','kurtosis_oxygen':'3.76497994','skewness_oxygen':'12.96997299'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [nan, 62.0] --> [62.0]
# capital-loss [nan, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [11.44230769, 11.44230769] --> [11.44230769]
# std_oxygen [43.47573632, 43.47573632] --> [43.47573632]
# kurtosis_oxygen [3.76497994, 3.76497994] --> [3.76497994]
# skewness_oxygen [12.96997299, 12.96997299] --> [12.96997299]
#
# Merging 2 rows of name Alex Williams...
# name ['Alex Williams', 'Alex Williams'] --> ['Alex Williams']
# address ['19143 Alexander Inlet\r\nKimside, VA 59139', '19143 Alexander Inlet\r\nKimside, VA 59139'] --> ['19143 Alexander Inlet\r\nKimside, VA 59139']
# race ['Asian-Pac-Islander', 'Asian-Pac-Islander'] --> ['Asian-Pac-Islander']
# marital-status [nan, 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Craft-repair', 'Craft-repair'] --> ['Craft-repair']
# pregnant ['f', 'f'] --> ['f']
# education-num [11.0, 11.0] --> [11.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [0.263671669, 0.263671669] --> [0.263671669]
# mean_glucose [147.8828125, 147.8828125] --> [147.8828125]
# capital-gain [0.0, 0.0] --> [0.0]
# ...
# address ['5486 Rosales Plain\r\nCollierfurt, OR 27682', '5486 Rosales Plain\r\nCollierfurt, OR 27682'] --> ['5486 Rosales Plain\r\nCollierfurt, OR 27682']
# race ['White', 'White'] --> ['White']
# marital-status ['Married-civ-spouse', 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Exec-managerial', 'Exec-managerial'] --> ['Exec-managerial']
# pregnant [nan, 'f'] --> ['f']
# education-num [13.0, 13.0] --> [13.0]
# relationship ['Husband', 'Husband'] --> ['Husband']
# skewness_glucose [1.189220477, 1.189220477] --> [1.189220477]
# mean_glucose [92.328125, 92.328125] --> [92.328125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.466215795, 0.466215795] --> [0.466215795]
# education ['Bachelors', nan] --> ['Bachelors']
# fnlwgt [201117.0, nan] --> [201117.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [43.60352433, nan] --> [43.60352433]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'1.475752508','std_oxygen':'11.6533794','kurtosis_oxygen':'14.96006331','skewness_oxygen':'281.4831447'}"] --> ["{'mean_oxygen':'1.475752508','std_oxygen':'11.6533794','kurtosis_oxygen':'14.96006331','skewness_oxygen':'281.4831447'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [50.0, 50.0] --> [50.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', nan] --> ['Private']
# mean_oxygen [0.0, 1.475752508] --> [1.475752508]
# std_oxygen [0.0, 11.6533794] --> [11.6533794]
# kurtosis_oxygen [0.0, 14.96006331] --> [14.96006331]
# skewness_oxygen [0.0, 281.4831447] --> [281.4831447]
#
# Merging 2 rows of name John Merkle...
# name ['John Merkle', 'John Merkle'] --> ['John Merkle']
# address ['48375 John Fords Suite 181\r\nLucasbury, ID 98399', '48375 John Fords Suite 181\r\nLucasbury, ID 98399'] --> ['48375 John Fords Suite 181\r\nLucasbury, ID 98399']
# race ['White', 'White'] --> ['White']
# marital-status ['Divorced', 'Divorced'] --> ['Divorced']
# occupation ['Sales', 'Sales'] --> ['Sales']
# pregnant ['f', nan] --> ['f']
# education-num [nan, 11.0] --> [11.0]
# relationship ['Not-in-family', 'Not-in-family'] --> ['Not-in-family']
# skewness_glucose [-0.297782152, nan] --> [-0.297782152]
# mean_glucose [115.46875, nan] --> [115.46875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.102520507, 0.102520507] --> [0.102520507]
# education ['Assoc-voc', nan] --> ['Assoc-voc']
# fnlwgt [80479.0, 80479.0] --> [80479.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [50.83535579, 50.83535579] --> [50.83535579]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'2.050167224','std_oxygen':'20.75411451','kurtosis_oxygen':'10.59644076','skewness_oxygen':'113.9303538'}", "{'mean_oxygen':'2.050167224','std_oxygen':'20.75411451','kurtosis_oxygen':'10.59644076','skewness_oxygen':'113.9303538'}"] --> ["{'mean_oxygen':'2.050167224','std_oxygen':'20.75411451','kurtosis_oxygen':'10.59644076','skewness_oxygen':'113.9303538'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', nan] --> ['Private']
# mean_oxygen [2.050167224, 2.050167224] --> [2.050167224]
# std_oxygen [20.75411451, 20.75411451] --> [20.75411451]
# kurtosis_oxygen [10.59644076, 10.59644076] --> [10.59644076]
# skewness_oxygen [113.9303538, 113.9303538] --> [113.9303538]
#
# Merging 2 rows of name Nicholas Reimer...
# name ['Nicholas Reimer', 'Nicholas Reimer'] --> ['Nicholas Reimer']
# address ['458 Moyer Mills Apt. 798\r\nChristianborough, AZ 57786', '458 Moyer Mills Apt. 798\r\nChristianborough, AZ 57786'] --> ['458 Moyer Mills Apt. 798\r\nChristianborough, AZ 57786']
# race [nan, nan] --> [nan]
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation ['Handlers-cleaners', 'Handlers-cleaners'] --> ['Handlers-cleaners']
# pregnant ['f', 'f'] --> ['f']
# education-num [7.0, 7.0] --> [7.0]
# relationship ['Not-in-family', 'Not-in-family'] --> ['Not-in-family']
# skewness_glucose [13.10581926, 13.10581926] --> [13.10581926]
# mean_glucose [17.0234375, 17.0234375] --> [17.0234375]
# capital-gain [nan, 0.0] --> [0.0]
# kurtosis_glucose [3.716950468, 3.716950468] --> [3.716950468]
# education ['11th', '11th'] --> ['11th']
# fnlwgt [493443.0, 493443.0] --> [493443.0]
# class [1.0, 1.0] --> [1.0]
# std_glucose [nan, nan] --> [nan]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'95.91220736','std_oxygen':'66.37242762','kurtosis_oxygen':'0.48443973','skewness_oxygen':'-0.438687261'}", "{'mean_oxygen':'95.91220736','std_oxygen':'66.37242762','kurtosis_oxygen':'0.48443973','skewness_oxygen':'-0.438687261'}"] --> ["{'mean_oxygen':'95.91220736','std_oxygen':'66.37242762','kurtosis_oxygen':'0.48443973','skewness_oxygen':'-0.438687261'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [40.0, nan] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass [nan, 'Private'] --> ['Private']
# mean_oxygen [95.91220736, 95.91220736] --> [95.91220736]
# std_oxygen [66.37242762, 66.37242762] --> [66.37242762]
# kurtosis_oxygen [0.48443973, 0.48443973] --> [0.48443973]
# skewness_oxygen [-0.438687261, -0.438687261] --> [-0.438687261]
#
# Merging 2 rows of name Edgar Nelson...
# name ['Edgar Nelson', 'Edgar Nelson'] --> ['Edgar Nelson']
# address ['1082 Alvarado Freeway\r\nBergermouth, VA 18698', '1082 Alvarado Freeway\r\nBergermouth, VA 18698'] --> ['1082 Alvarado Freeway\r\nBergermouth, VA 18698']
# race [nan, 'White'] --> ['White']
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation ['Prof-specialty', 'Prof-specialty'] --> ['Prof-specialty']
# pregnant [nan, 'f'] --> ['f']
# education-num [nan, 13.0] --> [13.0]
# relationship ['Not-in-family', 'Not-in-family'] --> ['Not-in-family']
# skewness_glucose [-0.320279745, -0.320279745] --> [-0.320279745]
# mean_glucose [117.3125, 117.3125] --> [117.3125]
# capital-gain [4650.0, 4650.0] --> [4650.0]
# kurtosis_glucose [0.272270124, 0.272270124] --> [0.272270124]
# education ['Bachelors', 'Bachelors'] --> ['Bachelors']
# fnlwgt [242619.0, 242619.0] --> [242619.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [47.242517600000006, 47.242517600000006] --> [47.242517600000006]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'2.119565217','std_oxygen':'13.57346856','kurtosis_oxygen':'10.2987034','skewness_oxygen':'138.69779540000002'}", "{'mean_oxygen':'2.119565217','std_oxygen':'13.57346856','kurtosis_oxygen':'10.2987034','skewness_oxygen':'138.69779540000002'}"] --> ["{'mean_oxygen':'2.119565217','std_oxygen':'13.57346856','kurtosis_oxygen':'10.2987034','skewness_oxygen':'138.69779540000002'}"]
# native-country [nan, 'United-States'] --> ['United-States']
# hours-per-week [nan, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [2.119565217, 2.119565217] --> [2.119565217]
# std_oxygen [13.57346856, 13.57346856] --> [13.57346856]
# kurtosis_oxygen [10.2987034, 10.2987034] --> [10.2987034]
# skewness_oxygen [138.69779540000002, 138.69779540000002] --> [138.69779540000002]
#
# Merging 2 rows of name Joel Cramer...
# name ['Joel Cramer', 'Joel Cramer'] --> ['Joel Cramer']
# address ['2074 Hernandez Creek\r\nLake Christopherfort, NC 20732', '2074 Hernandez Creek\r\nLake Christopherfort, NC 20732'] --> ['2074 Hernandez Creek\r\nLake Christopherfort, NC 20732']
# race ['White', 'White'] --> ['White']
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation ['Prof-specialty', 'Prof-specialty'] --> ['Prof-specialty']
# pregnant ['f', 'f'] --> ['f']
# education-num [10.0, 10.0] --> [10.0]
# relationship ['Own-child', nan] --> ['Own-child']
# skewness_glucose [1.669439566, nan] --> [1.669439566]
# mean_glucose [92.328125, 92.328125] --> [92.328125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [nan, 0.532109398] --> [0.532109398]
# education ['Some-college', nan] --> ['Some-college']
# fnlwgt [225724.0, 225724.0] --> [225724.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [3869.151017, 3869.151017] --> [3869.151017]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'3.660535117','std_oxygen':'24.73221427','kurtosis_oxygen':'7.24769215','skewness_oxygen':'54.05264117'}", "{'mean_oxygen':'3.660535117','std_oxygen':'24.73221427','kurtosis_oxygen':'7.24769215','skewness_oxygen':'54.05264117'}"] --> ["{'mean_oxygen':'3.660535117','std_oxygen':'24.73221427','kurtosis_oxygen':'7.24769215','skewness_oxygen':'54.05264117'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [25.0, 25.0] --> [25.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [3.660535117, 3.660535117] --> [3.660535117]
# std_oxygen [24.73221427, 24.73221427] --> [24.73221427]
# kurtosis_oxygen [7.24769215, 7.24769215] --> [7.24769215]
# skewness_oxygen [54.05264117, 54.05264117] --> [54.05264117]
#
# Merging 2 rows of name Curtis Benson...
# name ['Curtis Benson', 'Curtis Benson'] --> ['Curtis Benson']
# address ['70465 Michael Via Apt. 394\r\nSanchezview, WY 25004', '70465 Michael Via Apt. 394\r\nSanchezview, WY 25004'] --> ['70465 Michael Via Apt. 394\r\nSanchezview, WY 25004']
# race ['White', 'White'] --> ['White']
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation ['Other-service', 'Other-service'] --> ['Other-service']
# pregnant ['f', 'f'] --> ['f']
# education-num [11.0, 11.0] --> [11.0]
# relationship ['Own-child', nan] --> ['Own-child']
# skewness_glucose [0.213604545, 0.213604545] --> [0.213604545]
# mean_glucose [94.8125, 94.8125] --> [94.8125]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.4985249470000001, nan] --> [0.4985249470000001]
# education ['Assoc-voc', 'Assoc-voc'] --> ['Assoc-voc']
# fnlwgt [170800.0, nan] --> [170800.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [nan, 50.88878038] --> [50.88878038]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'0.488294314','std_oxygen':'9.561140874','kurtosis_oxygen':'22.47981278','skewness_oxygen':'538.0158217999998'}", "{'mean_oxygen':'0.488294314','std_oxygen':'9.561140874','kurtosis_oxygen':'22.47981278','skewness_oxygen':'538.0158217999998'}"] --> ["{'mean_oxygen':'0.488294314','std_oxygen':'9.561140874','kurtosis_oxygen':'22.47981278','skewness_oxygen':'538.0158217999998'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [12.0, 12.0] --> [12.0]
# capital-loss [0.0, nan] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [0.488294314, 0.488294314] --> [0.488294314]
# std_oxygen [9.561140874, 9.561140874] --> [9.561140874]
# kurtosis_oxygen [22.47981278, 22.47981278] --> [22.47981278]
# skewness_oxygen [538.0158217999998, 538.0158217999998] --> [538.0158217999998]
#
# Merging 2 rows of name Terrance Smith...
# name ['Terrance Smith', 'Terrance Smith'] --> ['Terrance Smith']
# address ['30338 Miller Coves\r\nLetown, TN 69998', '30338 Miller Coves\r\nLetown, TN 69998'] --> ['30338 Miller Coves\r\nLetown, TN 69998']
# race [nan, 'White'] --> ['White']
# marital-status ['Never-married', 'Never-married'] --> ['Never-married']
# occupation ['Other-service', nan] --> ['Other-service']
# pregnant ['FALSE', 'FALSE'] --> ['FALSE']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Own-child', 'Own-child'] --> ['Own-child']
# skewness_glucose [0.144185739, 0.144185739] --> [0.144185739]
# mean_glucose [126.9296875, 126.9296875] --> [126.9296875]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [0.076327609, 0.076327609] --> [0.076327609]
# education [nan, nan] --> [nan]
# fnlwgt [117595.0, 117595.0] --> [117595.0]
# class [nan, 0.0] --> [0.0]
# std_glucose [44.28956275, nan] --> [44.28956275]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'1.394648829','std_oxygen':'11.63864102','kurtosis_oxygen':'13.08523408','skewness_oxygen':'223.4211301'}", "{'mean_oxygen':'1.394648829','std_oxygen':'11.63864102','kurtosis_oxygen':'13.08523408','skewness_oxygen':'223.4211301'}"] --> ["{'mean_oxygen':'1.394648829','std_oxygen':'11.63864102','kurtosis_oxygen':'13.08523408','skewness_oxygen':'223.4211301'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [24.0, 24.0] --> [24.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [1.394648829, 1.394648829] --> [1.394648829]
# std_oxygen [11.63864102, 11.63864102] --> [11.63864102]
# kurtosis_oxygen [13.08523408, 13.08523408] --> [13.08523408]
# skewness_oxygen [223.4211301, 223.4211301] --> [223.4211301]
#
# Merging 2 rows of name Edward Hood...
# name ['Edward Hood', 'Edward Hood'] --> ['Edward Hood']
# address ['87749 Angela Glens Apt. 048\r\nNew Christopherview, UT 54245', '87749 Angela Glens Apt. 048\r\nNew Christopherview, UT 54245'] --> ['87749 Angela Glens Apt. 048\r\nNew Christopherview, UT 54245']
# race ['White', 'White'] --> ['White']
# marital-status [nan, 'Married-civ-spouse'] --> ['Married-civ-spouse']
# occupation ['Transport-moving', 'Transport-moving'] --> ['Transport-moving']
# pregnant ['f', 'f'] --> ['f']
# education-num [7.0, 7.0] --> [7.0]
# relationship ['Husband', nan] --> ['Husband']
# skewness_glucose [1.532026927, 1.532026927] --> [1.532026927]
# mean_glucose [94.65625, 94.65625] --> [94.65625]
# capital-gain [0.0, 0.0] --> [0.0]
# kurtosis_glucose [1.120508084, 1.120508084] --> [1.120508084]
# education ['11th', '11th'] --> ['11th']
# fnlwgt [150993.0, 150993.0] --> [150993.0]
# class [1.0, 1.0] --> [1.0]
# std_glucose [48.96577847, 48.96577847] --> [48.96577847]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info [nan, "{'mean_oxygen':'3.712374582','std_oxygen':'23.56963384','kurtosis_oxygen':'8.139562245','skewness_oxygen':'70.77428481'}"] --> ["{'mean_oxygen':'3.712374582','std_oxygen':'23.56963384','kurtosis_oxygen':'8.139562245','skewness_oxygen':'70.77428481'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [45.0, 45.0] --> [45.0]
# capital-loss [0.0, nan] --> [0.0]
# workclass ['Self-emp-not-inc', nan] --> ['Self-emp-not-inc']
# mean_oxygen [0.0, 3.712374582] --> [3.712374582]
# std_oxygen [0.0, 23.56963384] --> [23.56963384]
# kurtosis_oxygen [0.0, 8.139562245] --> [8.139562245]
# skewness_oxygen [0.0, 70.77428481] --> [70.77428481]
#
# Merging 2 rows of name Bernard Hilser...
# name ['Bernard Hilser', 'Bernard Hilser'] --> ['Bernard Hilser']
# address ['11425 Taylor Fall\r\nMikeside, SC 82575', '11425 Taylor Fall\r\nMikeside, SC 82575'] --> ['11425 Taylor Fall\r\nMikeside, SC 82575']
# race ['White', 'White'] --> ['White']
# marital-status [nan, 'Never-married'] --> ['Never-married']
# occupation ['Sales', 'Sales'] --> ['Sales']
# pregnant [nan, 'f'] --> ['f']
# education-num [9.0, 9.0] --> [9.0]
# relationship ['Own-child', 'Own-child'] --> ['Own-child']
# skewness_glucose [0.25922918100000003, 0.25922918100000003] --> [0.25922918100000003]
# mean_glucose [119.0546875, 119.0546875] --> [119.0546875]
# capital-gain [nan, 0.0] --> [0.0]
# kurtosis_glucose [nan, nan] --> [nan]
# education [nan, 'HS-grad'] --> ['HS-grad']
# fnlwgt [201799.0, 201799.0] --> [201799.0]
# class [0.0, 0.0] --> [0.0]
# std_glucose [-4212.913715, -4212.913715] --> [-4212.913715]
# income ['<=50K', '<=50K'] --> ['<=50K']
# medical_info ["{'mean_oxygen':'1.5903010030000002','std_oxygen':'14.48604586','kurtosis_oxygen':'11.68206794','skewness_oxygen':'158.7660883'}", "{'mean_oxygen':'1.5903010030000002','std_oxygen':'14.48604586','kurtosis_oxygen':'11.68206794','skewness_oxygen':'158.7660883'}"] --> ["{'mean_oxygen':'1.5903010030000002','std_oxygen':'14.48604586','kurtosis_oxygen':'11.68206794','skewness_oxygen':'158.7660883'}"]
# native-country ['United-States', 'United-States'] --> ['United-States']
# hours-per-week [40.0, 40.0] --> [40.0]
# capital-loss [0.0, 0.0] --> [0.0]
# workclass ['Private', 'Private'] --> ['Private']
# mean_oxygen [1.5903010030000002, 1.5903010030000002] --> [1.5903010030000002]
# std_oxygen [14.48604586, 14.48604586] --> [14.48604586]
# kurtosis_oxygen [11.68206794, 11.68206794] --> [11.68206794]
# skewness_oxygen [158.7660883, 158.7660883] --> [158.7660883]
# Applying changes...

# %%
# Fix the pregnant column values
data2['pregnant'] = data2['pregnant'].apply(lambda p: np.nan if str(p)=='nan' else p[0].lower()=='t')
print_col_values(data2)
# Out:
# ••► race (6): ['White', 'Amer-Indian-Eskimo', 'Black', 'Asian-Pac-Islander', 'Other', nan]
#
# ••► marital-status (7): ['Married-civ-spouse', 'Divorced', 'Never-married', 'Widowed', 'Married-spouse-absent', 'Separated', 'Married-AF-spouse']
#
# ••► occupation (15): ['Prof-specialty', 'Craft-repair', 'Tech-support', 'Transport-moving', 'Adm-clerical', 'Sales', 'Other-service', 'Exec-managerial', 'Machine-op-inspct', 'Protective-serv', 'Farming-fishing', 'Handlers-cleaners', '?', 'Priv-house-serv', 'Armed-Forces']
#
# ••► pregnant (3): [False, True, nan]
#
# ••► education-num (16): [12.0, 9.0, 10.0, 13.0, 11.0, 6.0, 16.0, 3.0, 14.0, 8.0, 5.0, 7.0, 4.0, 15.0, 2.0, 1.0]
#
# ••► relationship (6): ['Husband', 'Unmarried', 'Not-in-family', 'Own-child', 'Wife', 'Other-relative']
#
# ••► education (17): ['Assoc-acdm', 'HS-grad', 'Some-college', 'Bachelors', 'Assoc-voc', '10th', 'Doctorate', '5th-6th', 'Masters', '12th', '9th', '11th', '7th-8th', 'Prof-school', '1st-4th', 'Preschool', nan]
#
# ••► class (3): [0.0, 1.0, nan]
#
# ••► income (3): ['>50K', '<=50K', nan]
#
# ••► native-country (39): ['Canada', 'United-States', 'Mexico', 'France', 'Nicaragua', 'Cuba', 'Vietnam', '?', 'South', 'India', 'El-Salvador', 'Philippines', 'Guatemala', 'Portugal', 'Jamaica', 'England', 'Germany', 'Ecuador', 'Haiti', 'Japan', 'Puerto-Rico', 'Peru', 'Columbia', 'Iran', 'China', 'Greece', 'Thailand', 'Italy', 'Dominican-Republic', 'Laos', 'Taiwan', 'Ireland', 'Yugoslavia', 'Trinadad&Tobago', 'Cambodia', 'Poland', 'Honduras', 'Hong', 'Scotland']
#
# ••► workclass (8): ['Local-gov', 'Private', 'Self-emp-not-inc', 'Self-emp-inc', 'Federal-gov', 'State-gov', '?', 'Without-pay']

# %%
print('Filling nans with median values...')
data2med = data2
for c in data2.columns:
    med = data2[c].value_counts().idxmax() if type(data2.iloc[0][c]) == str else data2[c].median()
    print(c,'-->',med)
    data2med[c] = data2[c].apply(lambda v: med if is_nan(v) else v)
print('\n\nDone, column values:')
print_col_values(data2med)
# Out:
# Filling nans with median values...
# id --> 1975.0
# name --> Earl Hoffmann
# address --> 373 Christina Orchard Apt. 906
# New Aaron, MT 62228
# race --> White
# marital-status --> Married-civ-spouse
# occupation --> Prof-specialty
# pregnant --> 0.0
# education-num --> 10.0
# relationship --> Husband
# skewness_glucose --> 0.373827938
# mean_glucose --> 110.66015625
# capital-gain --> 0.0
# kurtosis_glucose --> 0.3110917095
# education --> HS-grad
# fnlwgt --> 177380.0
# class --> 0.0
# std_glucose --> 45.860094024999995
# income --> <=50K
# medical_info --> {'mean_oxygen':'103.0635452','std_oxygen':'77.65851827','kurtosis_oxygen':'0.088468245','skewness_oxygen':'-1.002333705'}
# native-country --> United-States
# hours-per-week --> 40.0
# capital-loss --> 0.0
# workclass --> Private
# mean_oxygen --> 3.236622074
# std_oxygen --> 20.56759309
# kurtosis_oxygen --> 7.782188139
# skewness_oxygen --> 68.4904738
#
#
# Done, column values:
# ••► race (5): ['White', 'Amer-Indian-Eskimo', 'Black', 'Asian-Pac-Islander', 'Other']
#
# ••► marital-status (7): ['Married-civ-spouse', 'Divorced', 'Never-married', 'Widowed', 'Married-spouse-absent', 'Separated', 'Married-AF-spouse']
#
# ••► occupation (14): ['Prof-specialty', 'Craft-repair', 'Tech-support', 'Transport-moving', 'Adm-clerical', 'Sales', 'Other-service', 'Exec-managerial', 'Machine-op-inspct', 'Protective-serv', 'Farming-fishing', 'Handlers-cleaners', 'Priv-house-serv', 'Armed-Forces']
#
# ••► pregnant (2): [False, True]
#
# ••► education-num (16): [12.0, 9.0, 10.0, 13.0, 11.0, 6.0, 16.0, 3.0, 14.0, 8.0, 5.0, 7.0, 4.0, 15.0, 2.0, 1.0]
#
# ••► relationship (6): ['Husband', 'Unmarried', 'Not-in-family', 'Own-child', 'Wife', 'Other-relative']
#
# ••► education (16): ['Assoc-acdm', 'HS-grad', 'Some-college', 'Bachelors', 'Assoc-voc', '10th', 'Doctorate', '5th-6th', 'Masters', '12th', '9th', '11th', '7th-8th', 'Prof-school', '1st-4th', 'Preschool']
#
# ••► class (2): [0.0, 1.0]
#
# ••► income (2): ['>50K', '<=50K']
#
# ••► native-country (38): ['Canada', 'United-States', 'Mexico', 'France', 'Nicaragua', 'Cuba', 'Vietnam', 'South', 'India', 'El-Salvador', 'Philippines', 'Guatemala', 'Portugal', 'Jamaica', 'England', 'Germany', 'Ecuador', 'Haiti', 'Japan', 'Puerto-Rico', 'Peru', 'Columbia', 'Iran', 'China', 'Greece', 'Thailand', 'Italy', 'Dominican-Republic', 'Laos', 'Taiwan', 'Ireland', 'Yugoslavia', 'Trinadad&Tobago', 'Cambodia', 'Poland', 'Honduras', 'Hong', 'Scotland']
#
# ••► workclass (7): ['Local-gov', 'Private', 'Self-emp-not-inc', 'Self-emp-inc', 'Federal-gov', 'State-gov', 'Without-pay']

# %%
std_g_pp = np.percentile(data2['std_glucose'], 95)
std_g_pp
# Out:
# 61.26677878999996

# %%
std_g_pm = np.percentile(data2['std_glucose'], 5)
std_g_pm
# Out:
# 27.667666832000002

# %%
def fix_std_g(x):
    if x > 200:
        x = std_g_pp
    if x < -200:
        x = std_g_pm
    return x

# %%
sea.distplot(data2['std_glucose'])

# %%
sea.distplot(data2['std_glucose'].apply(fix_std_g))

# %%
data2['std_glucose'] = data2['std_glucose'].apply(fix_std_g)

# %%
s_o_pp = np.percentile(data2['skewness_oxygen'], 95)
s_o_pp
# Out:
# 277.16984213999996

# %%
def fix_s_o(x):
    if x > 300:
        x = s_o_pp
    return x

# %%
sea.distplot(data2['skewness_oxygen'].apply(fix_s_o))

# %%
data2['skewness_oxygen'] = data2['skewness_oxygen'].apply(fix_s_o)

# %%
sea.distplot(data2['mean_oxygen'])

# %%
sea.distplot(np.log(data2['mean_oxygen'])

# %%
data2['mean_oxygen'] = np.log(data2['mean_oxygen'])

# %%
sea.distplot(data2['skewness_glucose'])

# %%
s_g_pp = np.percentile(data2['skewness_glucose'], 95)
s_g_pp

# %%
def fix_s_g(x):
    if x > 45:
        x = s_g_pp
    return x

# %%
sea.distplot(data2['skewness_glucose'].apply(fix_s_g))

# %%
data2['skewness_glucose'] = data2['skewness_glucose'].apply(fix_s_g)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3933 entries, 0 to 2774
# Data columns (total 27 columns):
# id                  3933 non-null int64
# name                3933 non-null object
# address             3933 non-null object
# race                3933 non-null object
# marital-status      3933 non-null object
# occupation          3933 non-null object
# pregnant            3933 non-null object
# education-num       3933 non-null float64
# relationship        3933 non-null object
# skewness_glucose    3933 non-null float64
# mean_glucose        3933 non-null float64
# capital-gain        3933 non-null float64
# kurtosis_glucose    3933 non-null float64
# education           3933 non-null object
# fnlwgt              3933 non-null float64
# class               3933 non-null float64
# std_glucose         3933 non-null float64
# income              3933 non-null object
# medical_info        3933 non-null object
# native-country      3933 non-null object
# hours-per-week      3933 non-null float64
# capital-loss        3933 non-null float64
# workclass           3933 non-null object
# mean_oxygen         3933 non-null float64
# std_oxygen          3933 non-null float64
# kurtosis_oxygen     3933 non-null float64
# skewness_oxygen     3933 non-null float64
# dtypes: float64(14), int64(1), object(12)
# memory usage: 860.3+ KB

# %%
data2.describe()
# Out:
#                 id  education-num  skewness_glucose  mean_glucose  \
# count  3933.000000    3933.000000       3933.000000   3933.000000
# mean   1982.612001      10.105009          4.218732    101.276629
# std    1150.233774       2.619360          9.678151     33.560005
# min       0.000000       1.000000         -1.755332      6.187500
# 25%     986.000000       9.000000         -0.119966     87.742188
# 50%    1975.000000      10.000000          0.373828    110.660156
# 75%    2980.000000      13.000000          2.081514    124.132812
# max    3982.000000      16.000000         68.101622    189.734375
#
#        capital-gain  kurtosis_glucose        fnlwgt        class  std_glucose  \
# count   3933.000000       3933.000000  3.933000e+03  3933.000000  3933.000000
# mean    1024.129163          0.951371  1.908705e+05     0.255276    45.090505
# std     7137.111662          1.610925  1.074328e+05     0.436072     8.520970
# min        0.000000         -1.641515  1.930200e+04     0.000000    25.695250
# 25%        0.000000          0.072331  1.182120e+05     0.000000    40.192414
# 50%        0.000000          0.311092  1.773800e+05     0.000000    45.860094
# 75%        0.000000          0.776762  2.379430e+05     1.000000    50.189640
# max    99999.000000          8.069522  1.268339e+06     1.000000    91.206475
#
#        hours-per-week  capital-loss  mean_oxygen   std_oxygen  \
# count     3933.000000   3933.000000  3933.000000  3933.000000
# mean        40.419019     89.845919     1.707456    31.153471
# std         12.152447    410.556963     1.427141    22.267181
# min          1.000000      0.000000    -1.545474     7.370432
# 25%         40.000000      0.000000     0.725235    15.040684
# 50%         40.000000      0.000000     1.174530    20.567593
# 75%         45.000000      0.000000     2.536176    43.221350
# max         99.000000   4356.000000     5.381607   110.642211
#
#        kurtosis_oxygen  skewness_oxygen
# count      3933.000000      3933.000000
# mean          7.413506        83.957927
# std           4.812170        79.550311
# min          -2.597872        -1.976976
# 25%           3.637833        12.866679
# 50%           7.782188        68.490474
# 75%          10.261581       127.012005
# max          34.539844       299.273578

# %%
print_col_values(data2)
# Out:
# ••► race (5): ['White', 'Amer-Indian-Eskimo', 'Black', 'Asian-Pac-Islander', 'Other']
#
# ••► marital-status (7): ['Married-civ-spouse', 'Divorced', 'Never-married', 'Widowed', 'Married-spouse-absent', 'Separated', 'Married-AF-spouse']
#
# ••► occupation (14): ['Prof-specialty', 'Craft-repair', 'Tech-support', 'Transport-moving', 'Adm-clerical', 'Sales', 'Other-service', 'Exec-managerial', 'Machine-op-inspct', 'Protective-serv', 'Farming-fishing', 'Handlers-cleaners', 'Priv-house-serv', 'Armed-Forces']
#
# ••► pregnant (2): [False, True]
#
# ••► education-num (16): [12.0, 9.0, 10.0, 13.0, 11.0, 6.0, 16.0, 3.0, 14.0, 8.0, 5.0, 7.0, 4.0, 15.0, 2.0, 1.0]
#
# ••► relationship (6): ['Husband', 'Unmarried', 'Not-in-family', 'Own-child', 'Wife', 'Other-relative']
#
# ••► education (16): ['Assoc-acdm', 'HS-grad', 'Some-college', 'Bachelors', 'Assoc-voc', '10th', 'Doctorate', '5th-6th', 'Masters', '12th', '9th', '11th', '7th-8th', 'Prof-school', '1st-4th', 'Preschool']
#
# ••► class (2): [0, 1]
#
# ••► income (2): ['>50K', '<=50K']
#
# ••► native-country (38): ['Canada', 'United-States', 'Mexico', 'France', 'Nicaragua', 'Cuba', 'Vietnam', 'South', 'India', 'El-Salvador', 'Philippines', 'Guatemala', 'Portugal', 'Jamaica', 'England', 'Germany', 'Ecuador', 'Haiti', 'Japan', 'Puerto-Rico', 'Peru', 'Columbia', 'Iran', 'China', 'Greece', 'Thailand', 'Italy', 'Dominican-Republic', 'Laos', 'Taiwan', 'Ireland', 'Yugoslavia', 'Trinadad&Tobago', 'Cambodia', 'Poland', 'Honduras', 'Hong', 'Scotland']
#
# ••► workclass (7): ['Local-gov', 'Private', 'Self-emp-not-inc', 'Self-emp-inc', 'Federal-gov', 'State-gov', 'Without-pay']

# %%
for gl in [
    "skewness_glucose",
    "mean_glucose",
    "kurtosis_glucose",
    "std_glucose",
    "mean_oxygen",
    "std_oxygen",
    "kurtosis_oxygen",
    "skewness_oxygen",
]:
    for cl in range(2):
        d = data2[data2["class"] == cl]
        draw_graph(gl + " - Class " + str(cl), d, gl)

# %%
data2['class'] = data2['class'].astype(int)
